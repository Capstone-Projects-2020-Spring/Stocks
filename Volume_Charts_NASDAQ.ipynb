# %%
#Install the dependencies
import numpy as np 
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib. pyplot as plt
import os

# %%
arr = []
with open("NASDAQ_ex.txt", "r") as filestream:
    for line in filestream:
        currentline = line.split(',')
        arr.append(currentline)
    stock_list = np.array(arr[0])


days = ['M', 'T', 'W', 'Th', 'F']
plt.clf()
for stock in stock_list:
    try:        
        print(stock)
        df = pd.read_csv("Stock_CSV/" + stock + '.csv') 
        df= df[['5. volume']]
        volumes = df.iloc[0:5].values
        result = volumes.ravel() 
        print(result)

        plt.bar(days, result, color = 'violet')
        plt.title('Average Volume per Day in Past Month')
        plt.xlabel('Days')
        plt.ylabel('Volume')
    #plt.show()

    
    
    # adding to plots_test folder
        plt.savefig('VOLUME_CHARTS/NASDAQ_volume_charts/' + stock + '.png')
        plt.clf()
    except pd.errors.EmptyDataError:
        print("Found empty file : {file}".format(file=file))
    # clears plot so that plots do not overlap on one plot
    #plt.clf()
# Out:
# AACG
# [ 7119.  3908. 16506. 10304.  3009.]
# AAL
# [66854629. 54598512. 76320112. 49882258. 58984927.]
# AAME
# [30481.    94.  2775.  7644.   885.]
# AAOI
# [783352. 495949. 566763. 754950. 673295.]
# AAPL
# [31274973. 31203582. 29264342. 45247893. 32503750.]
# AAWW
# [493679. 612064. 743780. 800571. 546205.]
# AAXJ
# [ 652515. 1039207.  556157.  663091.  940476.]
# AAXN
# [ 815924.  502777.  341503.  849611. 1562435.]
# ABCB
# [600119. 363773. 241140. 360081. 340851.]
# ABIO
# [10696.  8799. 23212. 20914. 25770.]
# ABMD
# [600499. 443853. 328531. 391060. 342852.]
# ABTX
# [53787. 92886. 78512. 87309. 76976.]
# ABUS
# [331291. 489259. 199163. 498268. 756737.]
# ACAD
# [1068117. 1014156. 1206106. 1046230. 1949572.]
# ACAMU
# [  5.  99. 800. 291. 100.]
# ACAMW
# [3.70000e+01 1.00000e+00 2.68670e+04 5.00000e+03 1.66866e+05]
# ACBI
# [63555. 60836. 32105. 34644. 30323.]
# ACER
# [15643. 23626. 44740. 20793. 49861.]
# ACGL
# [1955796. 1509750. 1992008. 1998017. 1890332.]
# ACGLP
# [37819. 37977. 27734. 54025. 27120.]
# ACHC
# [808753. 575068. 494045. 771632. 554425.]
# ACHV
# [2281815.  408713.  534162.  581216.  753467.]
# ACIA
# [286897. 584176. 273120. 466186. 439648.]
# ACIU
# [123769.  69231.  79669.  67070.  95772.]
# ACLS
# [202338. 167252. 142258. 220979. 249791.]
# ACMR
# [332056. 288639. 298980. 343695. 211478.]
# ACNB
# [14276. 21881. 19003. 15630. 12104.]
# ACOR
# [1182785. 1148777. 1047837. 1274790. 2550509.]
# ACRS
# [232581. 200081. 100418. 183798. 255850.]
# ACST
# [ 988403.  853237.  940238. 1618965. 6439252.]
# ACT
# [1525. 2413. 1551. 4955. 2097.]
# ACTG
# [ 64129. 104356. 145363. 170988. 240216.]
# ACTT
# [ 633.   26. 2244.  548.  933.]
# ACTTU
# [  0.   0.   0.   0. 100.]
# ACWI
# [4069893. 3718600. 4314185. 6007671. 5004307.]
# ACWX
# [5955829. 4025542. 1588572. 2826290. 3514640.]
# ADAP
# [ 83789. 104755. 153105. 112960. 284218.]
# ADBE
# [2127690. 2120251. 2231819. 3548202. 2771970.]
# ADES
# [114340. 141890. 132911. 131188. 119517.]
# ADIL
# [ 8029. 12038. 22203. 35618. 56728.]
# ADILW
# [4417.  510.  704.   80. 1380.]
# ADMA
# [2597137. 2341524. 1440166. 1973229. 1947893.]
# ADMP
# [1979232. 1325314. 1300502. 2922930. 1154501.]
# ADMS
# [108889. 163297. 164147. 272923. 384876.]
# ADPT
# [ 771876. 1298771.  874864.  526649.  921737.]
# ADRE
# [7878. 8225. 5126. 6866. 7034.]
# ADRO
# [394990. 264756. 299907. 346904. 588939.]
# ADSK
# [1145360. 1582439. 1013487. 2331901. 1191987.]
# ADTN
# [271814. 253518. 339829. 258722. 619392.]
# ADVM
# [ 825100.  824183.  928079. 1364885. 1700844.]
# ADXN
# [3.000e+02 2.535e+03 0.000e+00 1.000e+00 1.010e+03]
# ADXS
# [ 755102.  752612. 1154239. 1030830. 1104270.]
# AEGN
# [ 51610.  93291. 102701.  70362. 212825.]
# AEHR
# [ 8832.  8562. 54653. 23495. 20253.]
# AEMD
# [215278. 129624. 279577. 138973. 319856.]
# AERI
# [552021. 771177. 499451. 616650. 713082.]
# AESE
# [31377. 20005. 25492. 34230. 13866.]
# AEY
# [15624. 33850. 70571. 53365. 60597.]
# AEYE
# [98576. 54114. 55028. 90745. 66501.]
# AFH
# [89264. 67422. 89317. 26694. 84714.]
# AFIN
# [405679. 437365. 332986. 390508. 430732.]
# AFINP
# [20365. 14455. 24422. 43003. 47029.]
# AFMD
# [ 469933.  550990.  479978.  582807. 1148630.]
# AFYA
# [292433. 365912. 302160. 163358. 435389.]
# AGBAR
# [  51.  100. 1563.   75.   22.]
# AGBAU
# [0.00e+00 3.30e+01 5.00e+00 3.67e+04 2.78e+02]
# AGBAW
# [    0.  1400. 76826.   100.   333.]
# AGEN
# [1433246. 1296938. 1749744. 5271063. 4829793.]
# AGIO
# [810272. 593903. 347171. 816796. 921291.]
# AGLE
# [60450. 47102. 28802. 55838. 43494.]
# AGMH
# [2517. 2585. 2631. 2879. 2860.]
# AGNC
# [10683724.  7221828.  7655901. 11371557. 10599276.]
# AGNCM
# [65969. 50856. 63724. 28504. 56437.]
# AGNCO
# [ 80299.  61602.  92133. 110548.  82189.]
# AGNCP
# [156457. 122529.  48035. 130587. 120284.]
# AGND
# [5.49000e+02 7.00000e+00 2.18000e+02 1.41014e+05 1.08700e+03]
# AGRX
# [1162311. 1251240.  990869. 1425224. 1565121.]
# AGTC
# [101598. 179934. 119044.  99784. 136630.]
# AGZD
# [8125. 5751. 6511. 9897. 8895.]
# AHCO
# [ 56787.  51943.  38413. 361574. 140580.]
# AHPI
# [125067. 116336.  71112. 154045. 249783.]
# AIA
# [ 38752. 131979.  48699.  79823.  57397.]
# AIH
# [105462. 135015. 113434.  98629.  59888.]
# AIKI
# [ 3088221.  2364825.  4546141. 11973850.  3092171.]
# AIMC
# [275309. 362622. 391402. 467686. 530732.]
# AIMT
# [ 563577.  935513.  924553. 1074951. 2223251.]
# AINV
# [464267. 490047. 517228. 417676. 717467.]
# AIQ
# [15752.  6986. 35635. 11695. 38699.]
# AIRR
# [ 8791. 60465. 34473.  9338.  7351.]
# AIRT
# [2581.  155.  455. 1962. 3221.]
# AIRTP
# [400.   0. 116.   0.   3.]
# AIRTW
# [    0.  1831. 92604.  1060.  3479.]
# AKAM
# [2278116. 2273020. 1664028. 1462568. 2305102.]
# AKCA
# [163177. 256366. 236273. 126009. 167459.]
# AKER
# [2788131.  693161.  358322.  403640. 1589054.]
# AKRO
# [382046. 330074. 157157. 111299. 198842.]
# AKRX
# [16520348.  9054936.  8042570. 14145107. 53462046.]
# AKTS
# [ 733788.  992874. 2995081.  516360.  622594.]
# ALAC
# [6.00000e+00 2.86000e+02 1.50015e+05 1.51000e+02 1.10800e+04]
# ALACR
# [1.05793e+05 2.05750e+05 9.30000e+01 3.01900e+03 1.18300e+05]
# ALACU
# [  0.   0.   0.  31. 500.]
# ALACW
# [245937.  16137.  10500.   4546.  57281.]
# ALBO
# [53855. 52335. 47214. 61467. 44406.]
# ALDX
# [151301. 148563. 216504. 289822. 199419.]
# ALEC
# [362895. 310585. 338903. 199748. 382154.]
# ALGN
# [ 828038. 1013782. 1122492. 1051092. 1388165.]
# ALGR
# [ 0.  1. 38. 72.  0.]
# ALGRR
# [       0. 17137333. 41412966.  5445097.  2690532.]
# ALGRW
# [       0.  6250880. 24494256.  6456545. 10103677.]
# ALGT
# [144205. 261030. 331280. 185668. 169886.]
# ALIM
# [ 4320. 22042. 13089. 16611.  5933.]
# ALJJ
# [11063. 12609. 31498. 12196. 33850.]
# ALKS
# [1951810. 1221883. 2531502. 1649299. 2359317.]
# ALLO
# [545794. 487041. 345667. 550701. 773772.]
# ALLT
# [138890.  78877. 197704. 111433. 287025.]
# ALNA
# [324943. 393247. 538982. 982943. 507805.]
# ALNY
# [ 690647. 1092022.  383334. 1203432. 1469644.]
# ALOT
# [ 9725. 35064. 67846. 51038. 21668.]
# ALRM
# [290218. 302435. 302951. 269845. 363629.]
# ALRN
# [301540. 362885. 338651. 327521. 396289.]
# ALRS
# [38836. 13045.  7265.  5996. 12946.]
# ALSK
# [128675. 211433.  99021.  70641. 139069.]
# ALT
# [659023. 306154. 369340. 579360. 433374.]
# ALTR
# [121590. 146849. 201055. 254465. 296677.]
# ALTY
# [ 2527.  2159.  5619.  4374. 10256.]
# ALXN
# [1843687. 1295438. 1383013. 1698432. 3703316.]
# ALYA
# [1374. 3081. 1565.  711.  970.]
# AMAG
# [399022. 450604. 476284. 587123. 729017.]
# AMAT
# [7641379. 9048275. 7790213. 9359637. 7041189.]
# AMBA
# [223311. 262269. 253903. 403380. 486460.]
# AMCA
# [   0.    0.    8.   12. 2502.]
# AMCI
# [79981.   475.  1356.   961.   891.]
# AMCIU
# [ 437.    0.    0.  104. 1500.]
# AMCX
# [786672. 725085. 463416. 405498. 439007.]
# AMD
# [7.2518203e+07 6.9662688e+07 6.3164076e+07 1.2390639e+08 7.2367258e+07]
# AMED
# [217746. 229458. 217524. 222823. 264840.]
# AMEH
# [15618. 51004. 25685. 32836. 20798.]
# AMGN
# [1882767. 3226457. 2845168. 2672870. 2824060.]
# AMHCU
# [9.0e+00 9.2e+03 0.0e+00 0.0e+00 0.0e+00]
# AMHCW
# [0.0000e+00 3.0000e+04 6.0000e+01 6.3058e+04 6.1800e+04]
# AMKR
# [ 860546.  925000.  889643. 1385629.  701709.]
# AMNB
# [27588. 35430. 21183. 21793. 24553.]
# AMOT
# [60793. 31196. 48677. 57841. 88766.]
# AMRB
# [5218. 7204. 1862.  779. 1261.]
# AMRH
# [ 42241.  59641.  41250.  84369. 716629.]
# AMRHW
# [ 160. 1090.  335. 1094. 1564.]
# AMRK
# [16158. 16223. 12431.  3804. 11952.]
# AMRN
# [20686719.  8528222.  7018115.  9158718. 12880015.]
# AMSC
# [115125. 144629. 113129. 150541. 141248.]
# AMSF
# [124908. 105310.  72592.  73523.  89246.]
# AMSWA
# [583588. 184818. 120173. 105658. 116220.]
# AMTB
# [23968. 24310. 24177. 21581. 16227.]
# AMTBB
# [558. 472. 868. 834. 212.]
# AMTD
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-144-e10ca798c97f> in <module>
#      12     try:
#      13         print(stock)
# ---> 14         df = pd.read_csv("Stock_CSV/" + stock + '.csv')
#      15         df= df[['5. volume']]
#      16         volumes = df.iloc[0:5].values
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File Stock_CSV/AMTD.csv does not exist: 'Stock_CSV/AMTD.csv'

# %%
#days = ['M', 'T', 'W', 'Th', 'F']
#numbers = [1,2,3,4,5]

#plt.bar(days, numbers)
#plt.title('Average Volume per Day in Past Month for '+ stock)
#plt.xlabel('Days')
#plt.ylabel('Volume')
#plt.show()

# %%
import glob

path = "Stock_CSV/*.csv"
for fname in glob.glob(path):
    third_to_fifth_chars = fname[10:len(fname)]
    print(third_to_fifth_chars)
    third_to_fifth_chars = third_to_fifth_chars[:len(third_to_fifth_chars)-3]
    print(third_to_fifth_chars)
    print(fname)
    '''
    df = pd.read_csv(fname) 
    df= df[['5. volume']]
    volumes = df.iloc[0:5].values
    result = volumes.ravel() 
    print(result)
    
    plt.bar(days, result, color = 'violet')
    plt.title(third_to_fifth_chars + ': Average Volume per Day in Past Month')
    plt.xlabel('Days')
    plt.ylabel('Volume')
    #plt.show()

    
    
    # adding to plots_test folder
    plt.savefig('VOLUME_CHARTS/Test/' + third_to_fifth_chars + '.png')
    plt.clf()
    '''
# Out:
# ANTE.csv
# ANTE.
# Stock_CSV/ANTE.csv
# CSCO.csv
# CSCO.
# Stock_CSV/CSCO.csv
# LACQW.csv
# LACQW.
# Stock_CSV/LACQW.csv
# TOTA 2.csv
# TOTA 2.
# Stock_CSV/TOTA 2.csv
# HLNE.csv
# HLNE.
# Stock_CSV/HLNE.csv
# OCSI 2.csv
# OCSI 2.
# Stock_CSV/OCSI 2.csv
# PSM.csv
# PSM.
# Stock_CSV/PSM.csv
# SBGI.csv
# SBGI.
# Stock_CSV/SBGI.csv
# UFCS.csv
# UFCS.
# Stock_CSV/UFCS.csv
# GFED.csv
# GFED.
# Stock_CSV/GFED.csv
# PAVMZ 2.csv
# PAVMZ 2.
# Stock_CSV/PAVMZ 2.csv
# AIRT.csv
# AIRT.
# Stock_CSV/AIRT.csv
# SUSC 2.csv
# SUSC 2.
# Stock_CSV/SUSC 2.csv
# SMSI 2.csv
# SMSI 2.
# Stock_CSV/SMSI 2.csv
# NBL 2.csv
# NBL 2.
# Stock_CSV/NBL 2.csv
# ISSC.csv
# ISSC.
# Stock_CSV/ISSC.csv
# KNDI.csv
# KNDI.
# Stock_CSV/KNDI.csv
# THCBW 2.csv
# THCBW 2.
# Stock_CSV/THCBW 2.csv
# TRNS.csv
# TRNS.
# Stock_CSV/TRNS.csv
# TLND 2.csv
# TLND 2.
# Stock_CSV/TLND 2.csv
# TRIP 2.csv
# TRIP 2.
# Stock_CSV/TRIP 2.csv
# UAL.csv
# UAL.
# Stock_CSV/UAL.csv
# TROW.csv
# TROW.
# Stock_CSV/TROW.csv
# ISRG.csv
# ISRG.
# Stock_CSV/ISRG.csv
# TPCO 2.csv
# TPCO 2.
# Stock_CSV/TPCO 2.csv
# RDVY.csv
# RDVY.
# Stock_CSV/RDVY.csv
# TELA.csv
# TELA.
# Stock_CSV/TELA.csv
# RVSB 2.csv
# RVSB 2.
# Stock_CSV/RVSB 2.csv
# FEIM.csv
# FEIM.
# Stock_CSV/FEIM.csv
# SNSS 2.csv
# SNSS 2.
# Stock_CSV/SNSS 2.csv
# TLRY.csv
# TLRY.
# Stock_CSV/TLRY.csv
# LECO.csv
# LECO.
# Stock_CSV/LECO.csv
# VONG.csv
# VONG.
# Stock_CSV/VONG.csv
# VCYT.csv
# VCYT.
# Stock_CSV/VCYT.csv
# SGLB 2.csv
# SGLB 2.
# Stock_CSV/SGLB 2.csv
# PRGX.csv
# PRGX.
# Stock_CSV/PRGX.csv
# ORRF.csv
# ORRF.
# Stock_CSV/ORRF.csv
# NTRSO.csv
# NTRSO.
# Stock_CSV/NTRSO.csv
# RGCO 2.csv
# RGCO 2.
# Stock_CSV/RGCO 2.csv
# OESX.csv
# OESX.
# Stock_CSV/OESX.csv
# BLDP.csv
# BLDP.
# Stock_CSV/BLDP.csv
# SIBN.csv
# SIBN.
# Stock_CSV/SIBN.csv
# SOHOB 2.csv
# SOHOB 2.
# Stock_CSV/SOHOB 2.csv
# XCUR.csv
# XCUR.
# Stock_CSV/XCUR.csv
# YLCO.csv
# YLCO.
# Stock_CSV/YLCO.csv
# PDD.csv
# PDD.
# Stock_CSV/PDD.csv
# LBTYK.csv
# LBTYK.
# Stock_CSV/LBTYK.csv
# IMAB.csv
# IMAB.
# Stock_CSV/IMAB.csv
# SPOK.csv
# SPOK.
# Stock_CSV/SPOK.csv
# NDLS 2.csv
# NDLS 2.
# Stock_CSV/NDLS 2.csv
# TZACW.csv
# TZACW.
# Stock_CSV/TZACW.csv
# MGEE.csv
# MGEE.
# Stock_CSV/MGEE.csv
# MNCLU.csv
# MNCLU.
# Stock_CSV/MNCLU.csv
# AMSC.csv
# AMSC.
# Stock_CSV/AMSC.csv
# XLRN.csv
# XLRN.
# Stock_CSV/XLRN.csv
# SCYX.csv
# SCYX.
# Stock_CSV/SCYX.csv
# AIH.csv
# AIH.
# Stock_CSV/AIH.csv
# LOVE.csv
# LOVE.
# Stock_CSV/LOVE.csv
# ASYS.csv
# ASYS.
# Stock_CSV/ASYS.csv
# VIR.csv
# VIR.
# Stock_CSV/VIR.csv
# NEWA 2.csv
# NEWA 2.
# Stock_CSV/NEWA 2.csv
# SHBI 2.csv
# SHBI 2.
# Stock_CSV/SHBI 2.csv
# INSE.csv
# INSE.
# Stock_CSV/INSE.csv
# SVC.csv
# SVC.
# Stock_CSV/SVC.csv
# DVY.csv
# DVY.
# Stock_CSV/DVY.csv
# HAFC.csv
# HAFC.
# Stock_CSV/HAFC.csv
# BTAI.csv
# BTAI.
# Stock_CSV/BTAI.csv
# VIE.csv
# VIE.
# Stock_CSV/VIE.csv
# TCFCP 2.csv
# TCFCP 2.
# Stock_CSV/TCFCP 2.csv
# DPHC.csv
# DPHC.
# Stock_CSV/DPHC.csv
# ADTN.csv
# ADTN.
# Stock_CSV/ADTN.csv
# EQRR.csv
# EQRR.
# Stock_CSV/EQRR.csv
# BFRA.csv
# BFRA.
# Stock_CSV/BFRA.csv
# JVA.csv
# JVA.
# Stock_CSV/JVA.csv
# JNCE.csv
# JNCE.
# Stock_CSV/JNCE.csv
# SOCL.csv
# SOCL.
# Stock_CSV/SOCL.csv
# OFLX.csv
# OFLX.
# Stock_CSV/OFLX.csv
# DRRX.csv
# DRRX.
# Stock_CSV/DRRX.csv
# PSTI 2.csv
# PSTI 2.
# Stock_CSV/PSTI 2.csv
# NPAUU.csv
# NPAUU.
# Stock_CSV/NPAUU.csv
# MNCL.csv
# MNCL.
# Stock_CSV/MNCL.csv
# PHUNW.csv
# PHUNW.
# Stock_CSV/PHUNW.csv
# ASTC.csv
# ASTC.
# Stock_CSV/ASTC.csv
# NBIX.csv
# NBIX.
# Stock_CSV/NBIX.csv
# OCSI.csv
# OCSI.
# Stock_CSV/OCSI.csv
# WHLRD.csv
# WHLRD.
# Stock_CSV/WHLRD.csv
# QRTEA 2.csv
# QRTEA 2.
# Stock_CSV/QRTEA 2.csv
# VYGR.csv
# VYGR.
# Stock_CSV/VYGR.csv
# BA.csv
# BA.
# Stock_CSV/BA.csv
# VRTX.csv
# VRTX.
# Stock_CSV/VRTX.csv
# BRK.B.csv
# BRK.B.
# Stock_CSV/BRK.B.csv
# SSPK.csv
# SSPK.
# Stock_CSV/SSPK.csv
# GGAL.csv
# GGAL.
# Stock_CSV/GGAL.csv
# GILD.csv
# GILD.
# Stock_CSV/GILD.csv
# TRNX 2.csv
# TRNX 2.
# Stock_CSV/TRNX 2.csv
# SHSP.csv
# SHSP.
# Stock_CSV/SHSP.csv
# WW.csv
# WW.
# Stock_CSV/WW.csv
# NVIV 2.csv
# NVIV 2.
# Stock_CSV/NVIV 2.csv
# PNBK 2.csv
# PNBK 2.
# Stock_CSV/PNBK 2.csv
# YGYIP.csv
# YGYIP.
# Stock_CSV/YGYIP.csv
# MDB.csv
# MDB.
# Stock_CSV/MDB.csv
# SLM.csv
# SLM.
# Stock_CSV/SLM.csv
# FSCT.csv
# FSCT.
# Stock_CSV/FSCT.csv
# NYMTP.csv
# NYMTP.
# Stock_CSV/NYMTP.csv
# AMKR.csv
# AMKR.
# Stock_CSV/AMKR.csv
# FCFS.csv
# FCFS.
# Stock_CSV/FCFS.csv
# CLLS.csv
# CLLS.
# Stock_CSV/CLLS.csv
# VRAY.csv
# VRAY.
# Stock_CSV/VRAY.csv
# LOOP.csv
# LOOP.
# Stock_CSV/LOOP.csv
# CHY.csv
# CHY.
# Stock_CSV/CHY.csv
# TAYD.csv
# TAYD.
# Stock_CSV/TAYD.csv
# CREX.csv
# CREX.
# Stock_CSV/CREX.csv
# FYT.csv
# FYT.
# Stock_CSV/FYT.csv
# ACIU.csv
# ACIU.
# Stock_CSV/ACIU.csv
# XELA.csv
# XELA.
# Stock_CSV/XELA.csv
# TATT.csv
# TATT.
# Stock_CSV/TATT.csv
# WSTG.csv
# WSTG.
# Stock_CSV/WSTG.csv
# ESPO.csv
# ESPO.
# Stock_CSV/ESPO.csv
# PFMT.csv
# PFMT.
# Stock_CSV/PFMT.csv
# SUPN 2.csv
# SUPN 2.
# Stock_CSV/SUPN 2.csv
# FYC.csv
# FYC.
# Stock_CSV/FYC.csv
# VRNA.csv
# VRNA.
# Stock_CSV/VRNA.csv
# PFIE 2.csv
# PFIE 2.
# Stock_CSV/PFIE 2.csv
# TVTY.csv
# TVTY.
# Stock_CSV/TVTY.csv
# ESSC.csv
# ESSC.
# Stock_CSV/ESSC.csv
# ZG.csv
# ZG.
# Stock_CSV/ZG.csv
# STMP.csv
# STMP.
# Stock_CSV/STMP.csv
# FDNI.csv
# FDNI.
# Stock_CSV/FDNI.csv
# SIGA 2.csv
# SIGA 2.
# Stock_CSV/SIGA 2.csv
# DUOT.csv
# DUOT.
# Stock_CSV/DUOT.csv
# MSBF 2.csv
# MSBF 2.
# Stock_CSV/MSBF 2.csv
# IUSS.csv
# IUSS.
# Stock_CSV/IUSS.csv
# GURE.csv
# GURE.
# Stock_CSV/GURE.csv
# QUIK.csv
# QUIK.
# Stock_CSV/QUIK.csv
# MBOT.csv
# MBOT.
# Stock_CSV/MBOT.csv
# INFR.csv
# INFR.
# Stock_CSV/INFR.csv
# TER.csv
# TER.
# Stock_CSV/TER.csv
# HARP.csv
# HARP.
# Stock_CSV/HARP.csv
# MLCO.csv
# MLCO.
# Stock_CSV/MLCO.csv
# YJ.csv
# YJ.
# Stock_CSV/YJ.csv
# PHCF.csv
# PHCF.
# Stock_CSV/PHCF.csv
# SMBK.csv
# SMBK.
# Stock_CSV/SMBK.csv
# CDL.csv
# CDL.
# Stock_CSV/CDL.csv
# VRML.csv
# VRML.
# Stock_CSV/VRML.csv
# TZAC.csv
# TZAC.
# Stock_CSV/TZAC.csv
# PODD.csv
# PODD.
# Stock_CSV/PODD.csv
# RILYP.csv
# RILYP.
# Stock_CSV/RILYP.csv
# MDT.csv
# MDT.
# Stock_CSV/MDT.csv
# IPAR.csv
# IPAR.
# Stock_CSV/IPAR.csv
# RILYH 2.csv
# RILYH 2.
# Stock_CSV/RILYH 2.csv
# SND.csv
# SND.
# Stock_CSV/SND.csv
# AXSM.csv
# AXSM.
# Stock_CSV/AXSM.csv
# SAEX 2.csv
# SAEX 2.
# Stock_CSV/SAEX 2.csv
# BCYC.csv
# BCYC.
# Stock_CSV/BCYC.csv
# AMSWA.csv
# AMSWA.
# Stock_CSV/AMSWA.csv
# FORM.csv
# FORM.
# Stock_CSV/FORM.csv
# RILYG.csv
# RILYG.
# Stock_CSV/RILYG.csv
# FTR.csv
# FTR.
# Stock_CSV/FTR.csv
# SSKN 2.csv
# SSKN 2.
# Stock_CSV/SSKN 2.csv
# FUV.csv
# FUV.
# Stock_CSV/FUV.csv
# SMH.csv
# SMH.
# Stock_CSV/SMH.csv
# TSCAP.csv
# TSCAP.
# Stock_CSV/TSCAP.csv
# CPIX.csv
# CPIX.
# Stock_CSV/CPIX.csv
# RUHN 2.csv
# RUHN 2.
# Stock_CSV/RUHN 2.csv
# OBSV 2.csv
# OBSV 2.
# Stock_CSV/OBSV 2.csv
# QRVO.csv
# QRVO.
# Stock_CSV/QRVO.csv
# FAD.csv
# FAD.
# Stock_CSV/FAD.csv
# SALM.csv
# SALM.
# Stock_CSV/SALM.csv
# GEOS.csv
# GEOS.
# Stock_CSV/GEOS.csv
# TCBK 2.csv
# TCBK 2.
# Stock_CSV/TCBK 2.csv
# IRMD.csv
# IRMD.
# Stock_CSV/IRMD.csv
# RTIX 2.csv
# RTIX 2.
# Stock_CSV/RTIX 2.csv
# REKR.csv
# REKR.
# Stock_CSV/REKR.csv
# HBP.csv
# HBP.
# Stock_CSV/HBP.csv
# FOX.csv
# FOX.
# Stock_CSV/FOX.csv
# MTSC 2.csv
# MTSC 2.
# Stock_CSV/MTSC 2.csv
# PSCF.csv
# PSCF.
# Stock_CSV/PSCF.csv
# NVUS 2.csv
# NVUS 2.
# Stock_CSV/NVUS 2.csv
# HMSY.csv
# HMSY.
# Stock_CSV/HMSY.csv
# LK.csv
# LK.
# Stock_CSV/LK.csv
# REYN 2.csv
# REYN 2.
# Stock_CSV/REYN 2.csv
# HFBL.csv
# HFBL.
# Stock_CSV/HFBL.csv
# SAMAW.csv
# SAMAW.
# Stock_CSV/SAMAW.csv
# FNK.csv
# FNK.
# Stock_CSV/FNK.csv
# KBLMR.csv
# KBLMR.
# Stock_CSV/KBLMR.csv
# AVEO.csv
# AVEO.
# Stock_CSV/AVEO.csv
# SYNA 2.csv
# SYNA 2.
# Stock_CSV/SYNA 2.csv
# QURE 2.csv
# QURE 2.
# Stock_CSV/QURE 2.csv
# PERI 2.csv
# PERI 2.
# Stock_CSV/PERI 2.csv
# ICLK.csv
# ICLK.
# Stock_CSV/ICLK.csv
# IMAC.csv
# IMAC.
# Stock_CSV/IMAC.csv
# COFS.csv
# COFS.
# Stock_CSV/COFS.csv
# MCRI.csv
# MCRI.
# Stock_CSV/MCRI.csv
# SGMO.csv
# SGMO.
# Stock_CSV/SGMO.csv
# SWKS.csv
# SWKS.
# Stock_CSV/SWKS.csv
# USOI.csv
# USOI.
# Stock_CSV/USOI.csv
# FRPT.csv
# FRPT.
# Stock_CSV/FRPT.csv
# ALACR.csv
# ALACR.
# Stock_CSV/ALACR.csv
# ALYA.csv
# ALYA.
# Stock_CSV/ALYA.csv
# ZGNX.csv
# ZGNX.
# Stock_CSV/ZGNX.csv
# RCKT.csv
# RCKT.
# Stock_CSV/RCKT.csv
# PRPH 2.csv
# PRPH 2.
# Stock_CSV/PRPH 2.csv
# KRMA.csv
# KRMA.
# Stock_CSV/KRMA.csv
# SCYX 2.csv
# SCYX 2.
# Stock_CSV/SCYX 2.csv
# TBPH.csv
# TBPH.
# Stock_CSV/TBPH.csv
# PPSI.csv
# PPSI.
# Stock_CSV/PPSI.csv
# MFNC.csv
# MFNC.
# Stock_CSV/MFNC.csv
# FRSX.csv
# FRSX.
# Stock_CSV/FRSX.csv
# LPTH.csv
# LPTH.
# Stock_CSV/LPTH.csv
# PFM.csv
# PFM.
# Stock_CSV/PFM.csv
# VCTR.csv
# VCTR.
# Stock_CSV/VCTR.csv
# USAU.csv
# USAU.
# Stock_CSV/USAU.csv
# ENPH.csv
# ENPH.
# Stock_CSV/ENPH.csv
# SQBG 2.csv
# SQBG 2.
# Stock_CSV/SQBG 2.csv
# ITCI.csv
# ITCI.
# Stock_CSV/ITCI.csv
# HWCC.csv
# HWCC.
# Stock_CSV/HWCC.csv
# KNSA.csv
# KNSA.
# Stock_CSV/KNSA.csv
# BEAT.csv
# BEAT.
# Stock_CSV/BEAT.csv
# MHLD.csv
# MHLD.
# Stock_CSV/MHLD.csv
# IEC.csv
# IEC.
# Stock_CSV/IEC.csv
# OIIM.csv
# OIIM.
# Stock_CSV/OIIM.csv
# SNDE 2.csv
# SNDE 2.
# Stock_CSV/SNDE 2.csv
# APEI.csv
# APEI.
# Stock_CSV/APEI.csv
# TQQQ 2.csv
# TQQQ 2.
# Stock_CSV/TQQQ 2.csv
# NERV 2.csv
# NERV 2.
# Stock_CSV/NERV 2.csv
# GLADL.csv
# GLADL.
# Stock_CSV/GLADL.csv
# PBBI.csv
# PBBI.
# Stock_CSV/PBBI.csv
# NXTD.csv
# NXTD.
# Stock_CSV/NXTD.csv
# MARK.csv
# MARK.
# Stock_CSV/MARK.csv
# PACQU.csv
# PACQU.
# Stock_CSV/PACQU.csv
# BPOP.csv
# BPOP.
# Stock_CSV/BPOP.csv
# NMRK 2.csv
# NMRK 2.
# Stock_CSV/NMRK 2.csv
# SLGG.csv
# SLGG.
# Stock_CSV/SLGG.csv
# EYES.csv
# EYES.
# Stock_CSV/EYES.csv
# ICUI.csv
# ICUI.
# Stock_CSV/ICUI.csv
# MCHP.csv
# MCHP.
# Stock_CSV/MCHP.csv
# PBTS.csv
# PBTS.
# Stock_CSV/PBTS.csv
# RGEN 2.csv
# RGEN 2.
# Stock_CSV/RGEN 2.csv
# WRLSR.csv
# WRLSR.
# Stock_CSV/WRLSR.csv
# TROV.csv
# TROV.
# Stock_CSV/TROV.csv
# VCLT.csv
# VCLT.
# Stock_CSV/VCLT.csv
# SGEN 2.csv
# SGEN 2.
# Stock_CSV/SGEN 2.csv
# NVMI.csv
# NVMI.
# Stock_CSV/NVMI.csv
# FUNC.csv
# FUNC.
# Stock_CSV/FUNC.csv
# KRYS.csv
# KRYS.
# Stock_CSV/KRYS.csv
# MTEM.csv
# MTEM.
# Stock_CSV/MTEM.csv
# UNB.csv
# UNB.
# Stock_CSV/UNB.csv
# NFINU 2.csv
# NFINU 2.
# Stock_CSV/NFINU 2.csv
# ONVO 2.csv
# ONVO 2.
# Stock_CSV/ONVO 2.csv
# ARDX.csv
# ARDX.
# Stock_CSV/ARDX.csv
# TUES.csv
# TUES.
# Stock_CSV/TUES.csv
# PTVCA.csv
# PTVCA.
# Stock_CSV/PTVCA.csv
# STAF 2.csv
# STAF 2.
# Stock_CSV/STAF 2.csv
# PSL.csv
# PSL.
# Stock_CSV/PSL.csv
# MTBCP 2.csv
# MTBCP 2.
# Stock_CSV/MTBCP 2.csv
# LIND.csv
# LIND.
# Stock_CSV/LIND.csv
# BILI.csv
# BILI.
# Stock_CSV/BILI.csv
# DTEA.csv
# DTEA.
# Stock_CSV/DTEA.csv
# AEGN.csv
# AEGN.
# Stock_CSV/AEGN.csv
# SRAC.csv
# SRAC.
# Stock_CSV/SRAC.csv
# IVAC.csv
# IVAC.
# Stock_CSV/IVAC.csv
# LBC.csv
# LBC.
# Stock_CSV/LBC.csv
# FWONK.csv
# FWONK.
# Stock_CSV/FWONK.csv
# FLNT.csv
# FLNT.
# Stock_CSV/FLNT.csv
# MTEX.csv
# MTEX.
# Stock_CSV/MTEX.csv
# IBKCO.csv
# IBKCO.
# Stock_CSV/IBKCO.csv
# ULH.csv
# ULH.
# Stock_CSV/ULH.csv
# WLTW.csv
# WLTW.
# Stock_CSV/WLTW.csv
# ABCB.csv
# ABCB.
# Stock_CSV/ABCB.csv
# IFEU.csv
# IFEU.
# Stock_CSV/IFEU.csv
# MUDS 2.csv
# MUDS 2.
# Stock_CSV/MUDS 2.csv
# CHTR.csv
# CHTR.
# Stock_CSV/CHTR.csv
# HUBG.csv
# HUBG.
# Stock_CSV/HUBG.csv
# CORT.csv
# CORT.
# Stock_CSV/CORT.csv
# VSDA.csv
# VSDA.
# Stock_CSV/VSDA.csv
# ORGS.csv
# ORGS.
# Stock_CSV/ORGS.csv
# NTWK 2.csv
# NTWK 2.
# Stock_CSV/NTWK 2.csv
# MORF.csv
# MORF.
# Stock_CSV/MORF.csv
# TANNI 2.csv
# TANNI 2.
# Stock_CSV/TANNI 2.csv
# PLXS 2.csv
# PLXS 2.
# Stock_CSV/PLXS 2.csv
# SAIA 2.csv
# SAIA 2.
# Stock_CSV/SAIA 2.csv
# EGOV.csv
# EGOV.
# Stock_CSV/EGOV.csv
# CASH.csv
# CASH.
# Stock_CSV/CASH.csv
# TER 2.csv
# TER 2.
# Stock_CSV/TER 2.csv
# LNDC.csv
# LNDC.
# Stock_CSV/LNDC.csv
# SGLBW 2.csv
# SGLBW 2.
# Stock_CSV/SGLBW 2.csv
# TRMK.csv
# TRMK.
# Stock_CSV/TRMK.csv
# TESS 2.csv
# TESS 2.
# Stock_CSV/TESS 2.csv
# PACQW.csv
# PACQW.
# Stock_CSV/PACQW.csv
# AGRX.csv
# AGRX.
# Stock_CSV/AGRX.csv
# BYFC.csv
# BYFC.
# Stock_CSV/BYFC.csv
# SCZ 2.csv
# SCZ 2.
# Stock_CSV/SCZ 2.csv
# OFSSL 2.csv
# OFSSL 2.
# Stock_CSV/OFSSL 2.csv
# BNSO.csv
# BNSO.
# Stock_CSV/BNSO.csv
# IMMU.csv
# IMMU.
# Stock_CSV/IMMU.csv
# QABA.csv
# QABA.
# Stock_CSV/QABA.csv
# IEA.csv
# IEA.
# Stock_CSV/IEA.csv
# SHLO 2.csv
# SHLO 2.
# Stock_CSV/SHLO 2.csv
# CHMG.csv
# CHMG.
# Stock_CSV/CHMG.csv
# EPZM.csv
# EPZM.
# Stock_CSV/EPZM.csv
# OPK 2.csv
# OPK 2.
# Stock_CSV/OPK 2.csv
# BUG.csv
# BUG.
# Stock_CSV/BUG.csv
# NFINW 2.csv
# NFINW 2.
# Stock_CSV/NFINW 2.csv
# ISEM.csv
# ISEM.
# Stock_CSV/ISEM.csv
# NOVT.csv
# NOVT.
# Stock_CSV/NOVT.csv
# PEGA.csv
# PEGA.
# Stock_CSV/PEGA.csv
# SABR 2.csv
# SABR 2.
# Stock_CSV/SABR 2.csv
# PULM.csv
# PULM.
# Stock_CSV/PULM.csv
# NVCN 2.csv
# NVCN 2.
# Stock_CSV/NVCN 2.csv
# USMC.csv
# USMC.
# Stock_CSV/USMC.csv
# SURF.csv
# SURF.
# Stock_CSV/SURF.csv
# PDP.csv
# PDP.
# Stock_CSV/PDP.csv
# BROG.csv
# BROG.
# Stock_CSV/BROG.csv
# SUSB.csv
# SUSB.
# Stock_CSV/SUSB.csv
# CSWI.csv
# CSWI.
# Stock_CSV/CSWI.csv
# RCII.csv
# RCII.
# Stock_CSV/RCII.csv
# XSPA.csv
# XSPA.
# Stock_CSV/XSPA.csv
# CCRN.csv
# CCRN.
# Stock_CSV/CCRN.csv
# SCVL 2.csv
# SCVL 2.
# Stock_CSV/SCVL 2.csv
# SYBX 2.csv
# SYBX 2.
# Stock_CSV/SYBX 2.csv
# CXDC.csv
# CXDC.
# Stock_CSV/CXDC.csv
# FLXN.csv
# FLXN.
# Stock_CSV/FLXN.csv
# TUSK.csv
# TUSK.
# Stock_CSV/TUSK.csv
# WBA.csv
# WBA.
# Stock_CSV/WBA.csv
# DAIO.csv
# DAIO.
# Stock_CSV/DAIO.csv
# SUPN.csv
# SUPN.
# Stock_CSV/SUPN.csv
# CSTE.csv
# CSTE.
# Stock_CSV/CSTE.csv
# TRCH 2.csv
# TRCH 2.
# Stock_CSV/TRCH 2.csv
# GNPX.csv
# GNPX.
# Stock_CSV/GNPX.csv
# YTEN.csv
# YTEN.
# Stock_CSV/YTEN.csv
# AVGR.csv
# AVGR.
# Stock_CSV/AVGR.csv
# DLTH.csv
# DLTH.
# Stock_CSV/DLTH.csv
# RBBN.csv
# RBBN.
# Stock_CSV/RBBN.csv
# SAMAU.csv
# SAMAU.
# Stock_CSV/SAMAU.csv
# PTEN 2.csv
# PTEN 2.
# Stock_CSV/PTEN 2.csv
# ADXN.csv
# ADXN.
# Stock_CSV/ADXN.csv
# ZCZZT.csv
# ZCZZT.
# Stock_CSV/ZCZZT.csv
# ESGE.csv
# ESGE.
# Stock_CSV/ESGE.csv
# PSCF 2.csv
# PSCF 2.
# Stock_CSV/PSCF 2.csv
# ODT.csv
# ODT.
# Stock_CSV/ODT.csv
# MRAM 2.csv
# MRAM 2.
# Stock_CSV/MRAM 2.csv
# SVBI.csv
# SVBI.
# Stock_CSV/SVBI.csv
# PSCD.csv
# PSCD.
# Stock_CSV/PSCD.csv
# WHLRP.csv
# WHLRP.
# Stock_CSV/WHLRP.csv
# OTLKW 2.csv
# OTLKW 2.
# Stock_CSV/OTLKW 2.csv
# TSRI.csv
# TSRI.
# Stock_CSV/TSRI.csv
# ECOR.csv
# ECOR.
# Stock_CSV/ECOR.csv
# LAUR.csv
# LAUR.
# Stock_CSV/LAUR.csv
# EDIT.csv
# EDIT.
# Stock_CSV/EDIT.csv
# C.csv
# C.
# Stock_CSV/C.csv
# AY.csv
# AY.
# Stock_CSV/AY.csv
# DGII.csv
# DGII.
# Stock_CSV/DGII.csv
# SSSS.csv
# SSSS.
# Stock_CSV/SSSS.csv
# NRBO 2.csv
# NRBO 2.
# Stock_CSV/NRBO 2.csv
# BSJK.csv
# BSJK.
# Stock_CSV/BSJK.csv
# CRSA.csv
# CRSA.
# Stock_CSV/CRSA.csv
# VNET.csv
# VNET.
# Stock_CSV/VNET.csv
# FDTS.csv
# FDTS.
# Stock_CSV/FDTS.csv
# T.csv
# T.
# Stock_CSV/T.csv
# VICR.csv
# VICR.
# Stock_CSV/VICR.csv
# SINT 2.csv
# SINT 2.
# Stock_CSV/SINT 2.csv
# NHLD 2.csv
# NHLD 2.
# Stock_CSV/NHLD 2.csv
# SINO 2.csv
# SINO 2.
# Stock_CSV/SINO 2.csv
# DISH.csv
# DISH.
# Stock_CSV/DISH.csv
# RGEN.csv
# RGEN.
# Stock_CSV/RGEN.csv
# NEXT.csv
# NEXT.
# Stock_CSV/NEXT.csv
# GLRE.csv
# GLRE.
# Stock_CSV/GLRE.csv
# QIWI.csv
# QIWI.
# Stock_CSV/QIWI.csv
# NWFL.csv
# NWFL.
# Stock_CSV/NWFL.csv
# SYNC 2.csv
# SYNC 2.
# Stock_CSV/SYNC 2.csv
# NPAUU 2.csv
# NPAUU 2.
# Stock_CSV/NPAUU 2.csv
# EOLS.csv
# EOLS.
# Stock_CSV/EOLS.csv
# VG.csv
# VG.
# Stock_CSV/VG.csv
# GAINL.csv
# GAINL.
# Stock_CSV/GAINL.csv
# INBKZ.csv
# INBKZ.
# Stock_CSV/INBKZ.csv
# ATEX.csv
# ATEX.
# Stock_CSV/ATEX.csv
# ASRVP.csv
# ASRVP.
# Stock_CSV/ASRVP.csv
# SMMF.csv
# SMMF.
# Stock_CSV/SMMF.csv
# TCMD 2.csv
# TCMD 2.
# Stock_CSV/TCMD 2.csv
# QIWI 2.csv
# QIWI 2.
# Stock_CSV/QIWI 2.csv
# TCBI 2.csv
# TCBI 2.
# Stock_CSV/TCBI 2.csv
# SAVA.csv
# SAVA.
# Stock_CSV/SAVA.csv
# EMXC.csv
# EMXC.
# Stock_CSV/EMXC.csv
# ZS.csv
# ZS.
# Stock_CSV/ZS.csv
# XELB.csv
# XELB.
# Stock_CSV/XELB.csv
# NGHCZ 2.csv
# NGHCZ 2.
# Stock_CSV/NGHCZ 2.csv
# BCTF.csv
# BCTF.
# Stock_CSV/BCTF.csv
# PXLW 2.csv
# PXLW 2.
# Stock_CSV/PXLW 2.csv
# PCSB.csv
# PCSB.
# Stock_CSV/PCSB.csv
# RTH 2.csv
# RTH 2.
# Stock_CSV/RTH 2.csv
# ASMB.csv
# ASMB.
# Stock_CSV/ASMB.csv
# ACIA.csv
# ACIA.
# Stock_CSV/ACIA.csv
# IGOV.csv
# IGOV.
# Stock_CSV/IGOV.csv
# OFSSI.csv
# OFSSI.
# Stock_CSV/OFSSI.csv
# UEPS.csv
# UEPS.
# Stock_CSV/UEPS.csv
# MEIP.csv
# MEIP.
# Stock_CSV/MEIP.csv
# INDY.csv
# INDY.
# Stock_CSV/INDY.csv
# GNFT.csv
# GNFT.
# Stock_CSV/GNFT.csv
# SRTSW 2.csv
# SRTSW 2.
# Stock_CSV/SRTSW 2.csv
# PMD 2.csv
# PMD 2.
# Stock_CSV/PMD 2.csv
# HTIA.csv
# HTIA.
# Stock_CSV/HTIA.csv
# LOAN.csv
# LOAN.
# Stock_CSV/LOAN.csv
# ESSA.csv
# ESSA.
# Stock_CSV/ESSA.csv
# VRNT.csv
# VRNT.
# Stock_CSV/VRNT.csv
# ZCMD.csv
# ZCMD.
# Stock_CSV/ZCMD.csv
# REPL.csv
# REPL.
# Stock_CSV/REPL.csv
# SPWH 2.csv
# SPWH 2.
# Stock_CSV/SPWH 2.csv
# TQQQ.csv
# TQQQ.
# Stock_CSV/TQQQ.csv
# EVOK.csv
# EVOK.
# Stock_CSV/EVOK.csv
# SFM 2.csv
# SFM 2.
# Stock_CSV/SFM 2.csv
# SLDB 2.csv
# SLDB 2.
# Stock_CSV/SLDB 2.csv
# RWLK.csv
# RWLK.
# Stock_CSV/RWLK.csv
# NICE.csv
# NICE.
# Stock_CSV/NICE.csv
# YI.csv
# YI.
# Stock_CSV/YI.csv
# CBLI.csv
# CBLI.
# Stock_CSV/CBLI.csv
# IUSG.csv
# IUSG.
# Stock_CSV/IUSG.csv
# TITN 2.csv
# TITN 2.
# Stock_CSV/TITN 2.csv
# CBAY.csv
# CBAY.
# Stock_CSV/CBAY.csv
# MFH.csv
# MFH.
# Stock_CSV/MFH.csv
# WB.csv
# WB.
# Stock_CSV/WB.csv
# HJLI.csv
# HJLI.
# Stock_CSV/HJLI.csv
# STCN.csv
# STCN.
# Stock_CSV/STCN.csv
# OCGN.csv
# OCGN.
# Stock_CSV/OCGN.csv
# VBFC.csv
# VBFC.
# Stock_CSV/VBFC.csv
# MTP 2.csv
# MTP 2.
# Stock_CSV/MTP 2.csv
# GAINM.csv
# GAINM.
# Stock_CSV/GAINM.csv
# PLCE 2.csv
# PLCE 2.
# Stock_CSV/PLCE 2.csv
# SMTX 2.csv
# SMTX 2.
# Stock_CSV/SMTX 2.csv
# INBKL.csv
# INBKL.
# Stock_CSV/INBKL.csv
# CBAN.csv
# CBAN.
# Stock_CSV/CBAN.csv
# RRR 2.csv
# RRR 2.
# Stock_CSV/RRR 2.csv
# STAF.csv
# STAF.
# Stock_CSV/STAF.csv
# LJPC.csv
# LJPC.
# Stock_CSV/LJPC.csv
# NWGI.csv
# NWGI.
# Stock_CSV/NWGI.csv
# CIH.csv
# CIH.
# Stock_CSV/CIH.csv
# VIVE.csv
# VIVE.
# Stock_CSV/VIVE.csv
# SIVBP 2.csv
# SIVBP 2.
# Stock_CSV/SIVBP 2.csv
# GENC.csv
# GENC.
# Stock_CSV/GENC.csv
# PTCT 2.csv
# PTCT 2.
# Stock_CSV/PTCT 2.csv
# BCOM.csv
# BCOM.
# Stock_CSV/BCOM.csv
# CLXT.csv
# CLXT.
# Stock_CSV/CLXT.csv
# CG.csv
# CG.
# Stock_CSV/CG.csv
# CYAN.csv
# CYAN.
# Stock_CSV/CYAN.csv
# GLDI.csv
# GLDI.
# Stock_CSV/GLDI.csv
# SMTC 2.csv
# SMTC 2.
# Stock_CSV/SMTC 2.csv
# CNAT.csv
# CNAT.
# Stock_CSV/CNAT.csv
# NVFY 2.csv
# NVFY 2.
# Stock_CSV/NVFY 2.csv
# CBTX.csv
# CBTX.
# Stock_CSV/CBTX.csv
# WASH.csv
# WASH.
# Stock_CSV/WASH.csv
# TOWN 2.csv
# TOWN 2.
# Stock_CSV/TOWN 2.csv
# RDUS 2.csv
# RDUS 2.
# Stock_CSV/RDUS 2.csv
# TTTN.csv
# TTTN.
# Stock_CSV/TTTN.csv
# GWRS.csv
# GWRS.
# Stock_CSV/GWRS.csv
# ULBI.csv
# ULBI.
# Stock_CSV/ULBI.csv
# ASUR.csv
# ASUR.
# Stock_CSV/ASUR.csv
# HAIN.csv
# HAIN.
# Stock_CSV/HAIN.csv
# ODP 2.csv
# ODP 2.
# Stock_CSV/ODP 2.csv
# SRRA 2.csv
# SRRA 2.
# Stock_CSV/SRRA 2.csv
# HSTM.csv
# HSTM.
# Stock_CSV/HSTM.csv
# PSCE.csv
# PSCE.
# Stock_CSV/PSCE.csv
# SVA.csv
# SVA.
# Stock_CSV/SVA.csv
# INSG.csv
# INSG.
# Stock_CSV/INSG.csv
# CSF.csv
# CSF.
# Stock_CSV/CSF.csv
# NSEC 2.csv
# NSEC 2.
# Stock_CSV/NSEC 2.csv
# IGICW.csv
# IGICW.
# Stock_CSV/IGICW.csv
# ESGD.csv
# ESGD.
# Stock_CSV/ESGD.csv
# BSGM.csv
# BSGM.
# Stock_CSV/BSGM.csv
# SABR.csv
# SABR.
# Stock_CSV/SABR.csv
# SALM 2.csv
# SALM 2.
# Stock_CSV/SALM 2.csv
# MNCLW.csv
# MNCLW.
# Stock_CSV/MNCLW.csv
# PIZ 2.csv
# PIZ 2.
# Stock_CSV/PIZ 2.csv
# TZACU.csv
# TZACU.
# Stock_CSV/TZACU.csv
# ROKU 2.csv
# ROKU 2.
# Stock_CSV/ROKU 2.csv
# CSQ.csv
# CSQ.
# Stock_CSV/CSQ.csv
# OFIX 2.csv
# OFIX 2.
# Stock_CSV/OFIX 2.csv
# SILK 2.csv
# SILK 2.
# Stock_CSV/SILK 2.csv
# VKTX.csv
# VKTX.
# Stock_CSV/VKTX.csv
# PVBC 2.csv
# PVBC 2.
# Stock_CSV/PVBC 2.csv
# OPTN 2.csv
# OPTN 2.
# Stock_CSV/OPTN 2.csv
# REAL 2.csv
# REAL 2.
# Stock_CSV/REAL 2.csv
# NTGN 2.csv
# NTGN 2.
# Stock_CSV/NTGN 2.csv
# BOTJ.csv
# BOTJ.
# Stock_CSV/BOTJ.csv
# LDEM.csv
# LDEM.
# Stock_CSV/LDEM.csv
# SDGR 2.csv
# SDGR 2.
# Stock_CSV/SDGR 2.csv
# VTWG.csv
# VTWG.
# Stock_CSV/VTWG.csv
# PENN 2.csv
# PENN 2.
# Stock_CSV/PENN 2.csv
# WKEY.csv
# WKEY.
# Stock_CSV/WKEY.csv
# DFNL.csv
# DFNL.
# Stock_CSV/DFNL.csv
# ZEUS.csv
# ZEUS.
# Stock_CSV/ZEUS.csv
# THCBU 2.csv
# THCBU 2.
# Stock_CSV/THCBU 2.csv
# SUSC.csv
# SUSC.
# Stock_CSV/SUSC.csv
# VALU.csv
# VALU.
# Stock_CSV/VALU.csv
# MTSC.csv
# MTSC.
# Stock_CSV/MTSC.csv
# CODX.csv
# CODX.
# Stock_CSV/CODX.csv
# SKYS.csv
# SKYS.
# Stock_CSV/SKYS.csv
# BLDR.csv
# BLDR.
# Stock_CSV/BLDR.csv
# TURN.csv
# TURN.
# Stock_CSV/TURN.csv
# KRNY.csv
# KRNY.
# Stock_CSV/KRNY.csv
# PGJ.csv
# PGJ.
# Stock_CSV/PGJ.csv
# NATR.csv
# NATR.
# Stock_CSV/NATR.csv
# VTVT.csv
# VTVT.
# Stock_CSV/VTVT.csv
# ALTR.csv
# ALTR.
# Stock_CSV/ALTR.csv
# UTX.csv
# UTX.
# Stock_CSV/UTX.csv
# WIRE.csv
# WIRE.
# Stock_CSV/WIRE.csv
# PTVCA 2.csv
# PTVCA 2.
# Stock_CSV/PTVCA 2.csv
# AMRHW.csv
# AMRHW.
# Stock_CSV/AMRHW.csv
# PEZ 2.csv
# PEZ 2.
# Stock_CSV/PEZ 2.csv
# WISA.csv
# WISA.
# Stock_CSV/WISA.csv
# FGEN.csv
# FGEN.
# Stock_CSV/FGEN.csv
# LMRKP.csv
# LMRKP.
# Stock_CSV/LMRKP.csv
# NBN 2.csv
# NBN 2.
# Stock_CSV/NBN 2.csv
# VONE.csv
# VONE.
# Stock_CSV/VONE.csv
# NXTG.csv
# NXTG.
# Stock_CSV/NXTG.csv
# RDCM.csv
# RDCM.
# Stock_CSV/RDCM.csv
# TMDX 2.csv
# TMDX 2.
# Stock_CSV/TMDX 2.csv
# SINO.csv
# SINO.
# Stock_CSV/SINO.csv
# ZIOP.csv
# ZIOP.
# Stock_CSV/ZIOP.csv
# NTCT.csv
# NTCT.
# Stock_CSV/NTCT.csv
# ENSG.csv
# ENSG.
# Stock_CSV/ENSG.csv
# LNT.csv
# LNT.
# Stock_CSV/LNT.csv
# CARZ.csv
# CARZ.
# Stock_CSV/CARZ.csv
# OCC 2.csv
# OCC 2.
# Stock_CSV/OCC 2.csv
# CDLX.csv
# CDLX.
# Stock_CSV/CDLX.csv
# RTRX.csv
# RTRX.
# Stock_CSV/RTRX.csv
# VMBS.csv
# VMBS.
# Stock_CSV/VMBS.csv
# BAC.csv
# BAC.
# Stock_CSV/BAC.csv
# STRL 2.csv
# STRL 2.
# Stock_CSV/STRL 2.csv
# HBMD.csv
# HBMD.
# Stock_CSV/HBMD.csv
# NDRA.csv
# NDRA.
# Stock_CSV/NDRA.csv
# SPI 2.csv
# SPI 2.
# Stock_CSV/SPI 2.csv
# KRUS.csv
# KRUS.
# Stock_CSV/KRUS.csv
# SMIT 2.csv
# SMIT 2.
# Stock_CSV/SMIT 2.csv
# EYEG.csv
# EYEG.
# Stock_CSV/EYEG.csv
# VTNR.csv
# VTNR.
# Stock_CSV/VTNR.csv
# LEVL.csv
# LEVL.
# Stock_CSV/LEVL.csv
# BKYI.csv
# BKYI.
# Stock_CSV/BKYI.csv
# HYXE.csv
# HYXE.
# Stock_CSV/HYXE.csv
# CASI.csv
# CASI.
# Stock_CSV/CASI.csv
# CAPR.csv
# CAPR.
# Stock_CSV/CAPR.csv
# FNWB.csv
# FNWB.
# Stock_CSV/FNWB.csv
# ZWZZT.csv
# ZWZZT.
# Stock_CSV/ZWZZT.csv
# ALLT.csv
# ALLT.
# Stock_CSV/ALLT.csv
# FRGI.csv
# FRGI.
# Stock_CSV/FRGI.csv
# PPC.csv
# PPC.
# Stock_CSV/PPC.csv
# PPH 2.csv
# PPH 2.
# Stock_CSV/PPH 2.csv
# WVE.csv
# WVE.
# Stock_CSV/WVE.csv
# EVSIW.csv
# EVSIW.
# Stock_CSV/EVSIW.csv
# SXTC 2.csv
# SXTC 2.
# Stock_CSV/SXTC 2.csv
# LACQU.csv
# LACQU.
# Stock_CSV/LACQU.csv
# AVGOP.csv
# AVGOP.
# Stock_CSV/AVGOP.csv
# IBKCN.csv
# IBKCN.
# Stock_CSV/IBKCN.csv
# RFAP.csv
# RFAP.
# Stock_CSV/RFAP.csv
# PETQ 2.csv
# PETQ 2.
# Stock_CSV/PETQ 2.csv
# PTVCB.csv
# PTVCB.
# Stock_CSV/PTVCB.csv
# FLMN.csv
# FLMN.
# Stock_CSV/FLMN.csv
# MCEP.csv
# MCEP.
# Stock_CSV/MCEP.csv
# SRCL.csv
# SRCL.
# Stock_CSV/SRCL.csv
# DFPHU.csv
# DFPHU.
# Stock_CSV/DFPHU.csv
# HCAPZ.csv
# HCAPZ.
# Stock_CSV/HCAPZ.csv
# SONGW.csv
# SONGW.
# Stock_CSV/SONGW.csv
# AIRR.csv
# AIRR.
# Stock_CSV/AIRR.csv
# IMTE.csv
# IMTE.
# Stock_CSV/IMTE.csv
# NVCR.csv
# NVCR.
# Stock_CSV/NVCR.csv
# MDCA.csv
# MDCA.
# Stock_CSV/MDCA.csv
# TECH.csv
# TECH.
# Stock_CSV/TECH.csv
# PROF 2.csv
# PROF 2.
# Stock_CSV/PROF 2.csv
# PGEN.csv
# PGEN.
# Stock_CSV/PGEN.csv
# AUBN.csv
# AUBN.
# Stock_CSV/AUBN.csv
# LINC.csv
# LINC.
# Stock_CSV/LINC.csv
# NXPI 2.csv
# NXPI 2.
# Stock_CSV/NXPI 2.csv
# PUYI.csv
# PUYI.
# Stock_CSV/PUYI.csv
# WWR.csv
# WWR.
# Stock_CSV/WWR.csv
# SSPKU.csv
# SSPKU.
# Stock_CSV/SSPKU.csv
# NNBR 2.csv
# NNBR 2.
# Stock_CSV/NNBR 2.csv
# LYFT.csv
# LYFT.
# Stock_CSV/LYFT.csv
# RETA 2.csv
# RETA 2.
# Stock_CSV/RETA 2.csv
# RSSS 2.csv
# RSSS 2.
# Stock_CSV/RSSS 2.csv
# TENX.csv
# TENX.
# Stock_CSV/TENX.csv
# HLAL.csv
# HLAL.
# Stock_CSV/HLAL.csv
# SSSS 2.csv
# SSSS 2.
# Stock_CSV/SSSS 2.csv
# RDUS.csv
# RDUS.
# Stock_CSV/RDUS.csv
# BNGO.csv
# BNGO.
# Stock_CSV/BNGO.csv
# WRLSU.csv
# WRLSU.
# Stock_CSV/WRLSU.csv
# OSPN 2.csv
# OSPN 2.
# Stock_CSV/OSPN 2.csv
# OSTK 2.csv
# OSTK 2.
# Stock_CSV/OSTK 2.csv
# CDMO.csv
# CDMO.
# Stock_CSV/CDMO.csv
# OKTA 2.csv
# OKTA 2.
# Stock_CSV/OKTA 2.csv
# ODT 2.csv
# ODT 2.
# Stock_CSV/ODT 2.csv
# FUND.csv
# FUND.
# Stock_CSV/FUND.csv
# TIPT 2.csv
# TIPT 2.
# Stock_CSV/TIPT 2.csv
# PRFZ.csv
# PRFZ.
# Stock_CSV/PRFZ.csv
# PSEC 2.csv
# PSEC 2.
# Stock_CSV/PSEC 2.csv
# TANH 2.csv
# TANH 2.
# Stock_CSV/TANH 2.csv
# LLIT.csv
# LLIT.
# Stock_CSV/LLIT.csv
# HYLS.csv
# HYLS.
# Stock_CSV/HYLS.csv
# SILC.csv
# SILC.
# Stock_CSV/SILC.csv
# PIE.csv
# PIE.
# Stock_CSV/PIE.csv
# VONV.csv
# VONV.
# Stock_CSV/VONV.csv
# DXJS.csv
# DXJS.
# Stock_CSV/DXJS.csv
# PXI 2.csv
# PXI 2.
# Stock_CSV/PXI 2.csv
# APEN.csv
# APEN.
# Stock_CSV/APEN.csv
# IMMP.csv
# IMMP.
# Stock_CSV/IMMP.csv
# ICCC.csv
# ICCC.
# Stock_CSV/ICCC.csv
# HNNA.csv
# HNNA.
# Stock_CSV/HNNA.csv
# FLWS.csv
# FLWS.
# Stock_CSV/FLWS.csv
# NXTC.csv
# NXTC.
# Stock_CSV/NXTC.csv
# LIVE.csv
# LIVE.
# Stock_CSV/LIVE.csv
# OVBC 2.csv
# OVBC 2.
# Stock_CSV/OVBC 2.csv
# ZAZZT.csv
# ZAZZT.
# Stock_CSV/ZAZZT.csv
# PEIX.csv
# PEIX.
# Stock_CSV/PEIX.csv
# MSTR.csv
# MSTR.
# Stock_CSV/MSTR.csv
# TBPH 2.csv
# TBPH 2.
# Stock_CSV/TBPH 2.csv
# FDUSL.csv
# FDUSL.
# Stock_CSV/FDUSL.csv
# CHCI.csv
# CHCI.
# Stock_CSV/CHCI.csv
# WPRT.csv
# WPRT.
# Stock_CSV/WPRT.csv
# NTCT 2.csv
# NTCT 2.
# Stock_CSV/NTCT 2.csv
# PIE 2.csv
# PIE 2.
# Stock_CSV/PIE 2.csv
# ITMR.csv
# ITMR.
# Stock_CSV/ITMR.csv
# BKCC.csv
# BKCC.
# Stock_CSV/BKCC.csv
# LPTX.csv
# LPTX.
# Stock_CSV/LPTX.csv
# HERD.csv
# HERD.
# Stock_CSV/HERD.csv
# MDWD.csv
# MDWD.
# Stock_CSV/MDWD.csv
# ANAB.csv
# ANAB.
# Stock_CSV/ANAB.csv
# ALACU.csv
# ALACU.
# Stock_CSV/ALACU.csv
# SKYW.csv
# SKYW.
# Stock_CSV/SKYW.csv
# HYAC.csv
# HYAC.
# Stock_CSV/HYAC.csv
# GTLS.csv
# GTLS.
# Stock_CSV/GTLS.csv
# PLCE.csv
# PLCE.
# Stock_CSV/PLCE.csv
# WBND.csv
# WBND.
# Stock_CSV/WBND.csv
# USLB.csv
# USLB.
# Stock_CSV/USLB.csv
# NAVI.csv
# NAVI.
# Stock_CSV/NAVI.csv
# PTGX.csv
# PTGX.
# Stock_CSV/PTGX.csv
# GYRO.csv
# GYRO.
# Stock_CSV/GYRO.csv
# PTI 2.csv
# PTI 2.
# Stock_CSV/PTI 2.csv
# CSB.csv
# CSB.
# Stock_CSV/CSB.csv
# RGLD 2.csv
# RGLD 2.
# Stock_CSV/RGLD 2.csv
# SFET.csv
# SFET.
# Stock_CSV/SFET.csv
# INPX.csv
# INPX.
# Stock_CSV/INPX.csv
# VIOT.csv
# VIOT.
# Stock_CSV/VIOT.csv
# JCTCF.csv
# JCTCF.
# Stock_CSV/JCTCF.csv
# BSDE.csv
# BSDE.
# Stock_CSV/BSDE.csv
# SONGW 2.csv
# SONGW 2.
# Stock_CSV/SONGW 2.csv
# REFR.csv
# REFR.
# Stock_CSV/REFR.csv
# GFNSL.csv
# GFNSL.
# Stock_CSV/GFNSL.csv
# MYOS.csv
# MYOS.
# Stock_CSV/MYOS.csv
# SPNE 2.csv
# SPNE 2.
# Stock_CSV/SPNE 2.csv
# SONM.csv
# SONM.
# Stock_CSV/SONM.csv
# KBLMU.csv
# KBLMU.
# Stock_CSV/KBLMU.csv
# IIVI.csv
# IIVI.
# Stock_CSV/IIVI.csv
# TEUM 2.csv
# TEUM 2.
# Stock_CSV/TEUM 2.csv
# BFST.csv
# BFST.
# Stock_CSV/BFST.csv
# ATSG.csv
# ATSG.
# Stock_CSV/ATSG.csv
# LMBS.csv
# LMBS.
# Stock_CSV/LMBS.csv
# EXPCW.csv
# EXPCW.
# Stock_CSV/EXPCW.csv
# ASTE.csv
# ASTE.
# Stock_CSV/ASTE.csv
# ATRC.csv
# ATRC.
# Stock_CSV/ATRC.csv
# BSJN.csv
# BSJN.
# Stock_CSV/BSJN.csv
# UEIC.csv
# UEIC.
# Stock_CSV/UEIC.csv
# PRGX 2.csv
# PRGX 2.
# Stock_CSV/PRGX 2.csv
# XNET.csv
# XNET.
# Stock_CSV/XNET.csv
# JRSH.csv
# JRSH.
# Stock_CSV/JRSH.csv
# VETS.csv
# VETS.
# Stock_CSV/VETS.csv
# VLGEA.csv
# VLGEA.
# Stock_CSV/VLGEA.csv
# GWPH.csv
# GWPH.
# Stock_CSV/GWPH.csv
# F.csv
# F.
# Stock_CSV/F.csv
# FAT.csv
# FAT.
# Stock_CSV/FAT.csv
# ECOW.csv
# ECOW.
# Stock_CSV/ECOW.csv
# NBLX 2.csv
# NBLX 2.
# Stock_CSV/NBLX 2.csv
# TZOO.csv
# TZOO.
# Stock_CSV/TZOO.csv
# ADBE.csv
# ADBE.
# Stock_CSV/ADBE.csv
# JAN.csv
# JAN.
# Stock_CSV/JAN.csv
# SMMC.csv
# SMMC.
# Stock_CSV/SMMC.csv
# CYTK.csv
# CYTK.
# Stock_CSV/CYTK.csv
# MLNX.csv
# MLNX.
# Stock_CSV/MLNX.csv
# HMHC.csv
# HMHC.
# Stock_CSV/HMHC.csv
# AACG 2.csv
# AACG 2.
# Stock_CSV/AACG 2.csv
# CIL.csv
# CIL.
# Stock_CSV/CIL.csv
# LONE.csv
# LONE.
# Stock_CSV/LONE.csv
# OTEX.csv
# OTEX.
# Stock_CSV/OTEX.csv
# STRS 2.csv
# STRS 2.
# Stock_CSV/STRS 2.csv
# NEPT 2.csv
# NEPT 2.
# Stock_CSV/NEPT 2.csv
# SMMT.csv
# SMMT.
# Stock_CSV/SMMT.csv
# RTLR 2.csv
# RTLR 2.
# Stock_CSV/RTLR 2.csv
# PAHC 2.csv
# PAHC 2.
# Stock_CSV/PAHC 2.csv
# RIGL.csv
# RIGL.
# Stock_CSV/RIGL.csv
# CLAR.csv
# CLAR.
# Stock_CSV/CLAR.csv
# RNWK 2.csv
# RNWK 2.
# Stock_CSV/RNWK 2.csv
# AMEH.csv
# AMEH.
# Stock_CSV/AMEH.csv
# OFSSL.csv
# OFSSL.
# Stock_CSV/OFSSL.csv
# NETE.csv
# NETE.
# Stock_CSV/NETE.csv
# BANX.csv
# BANX.
# Stock_CSV/BANX.csv
# SMBC 2.csv
# SMBC 2.
# Stock_CSV/SMBC 2.csv
# VEON.csv
# VEON.
# Stock_CSV/VEON.csv
# RYAAY.csv
# RYAAY.
# Stock_CSV/RYAAY.csv
# GRTS.csv
# GRTS.
# Stock_CSV/GRTS.csv
# MBINP.csv
# MBINP.
# Stock_CSV/MBINP.csv
# RDI 2.csv
# RDI 2.
# Stock_CSV/RDI 2.csv
# SAL.csv
# SAL.
# Stock_CSV/SAL.csv
# QRVO 2.csv
# QRVO 2.
# Stock_CSV/QRVO 2.csv
# SOLY 2.csv
# SOLY 2.
# Stock_CSV/SOLY 2.csv
# TCOM.csv
# TCOM.
# Stock_CSV/TCOM.csv
# REPH.csv
# REPH.
# Stock_CSV/REPH.csv
# STLD.csv
# STLD.
# Stock_CSV/STLD.csv
# PSTI.csv
# PSTI.
# Stock_CSV/PSTI.csv
# OFSSZ.csv
# OFSSZ.
# Stock_CSV/OFSSZ.csv
# NURO.csv
# NURO.
# Stock_CSV/NURO.csv
# LCUT.csv
# LCUT.
# Stock_CSV/LCUT.csv
# TTMI.csv
# TTMI.
# Stock_CSV/TTMI.csv
# OPB.csv
# OPB.
# Stock_CSV/OPB.csv
# IUSB.csv
# IUSB.
# Stock_CSV/IUSB.csv
# SMCI.csv
# SMCI.
# Stock_CSV/SMCI.csv
# PFLT 2.csv
# PFLT 2.
# Stock_CSV/PFLT 2.csv
# ACHV.csv
# ACHV.
# Stock_CSV/ACHV.csv
# REKR 2.csv
# REKR 2.
# Stock_CSV/REKR 2.csv
# CPRT.csv
# CPRT.
# Stock_CSV/CPRT.csv
# SCOR.csv
# SCOR.
# Stock_CSV/SCOR.csv
# BSQR.csv
# BSQR.
# Stock_CSV/BSQR.csv
# MRIN.csv
# MRIN.
# Stock_CSV/MRIN.csv
# OSMT.csv
# OSMT.
# Stock_CSV/OSMT.csv
# CEY.csv
# CEY.
# Stock_CSV/CEY.csv
# OSN.csv
# OSN.
# Stock_CSV/OSN.csv
# TCMD.csv
# TCMD.
# Stock_CSV/TCMD.csv
# SNDX 2.csv
# SNDX 2.
# Stock_CSV/SNDX 2.csv
# GPAQ.csv
# GPAQ.
# Stock_CSV/GPAQ.csv
# NK 2.csv
# NK 2.
# Stock_CSV/NK 2.csv
# LQDT.csv
# LQDT.
# Stock_CSV/LQDT.csv
# AMHCU.csv
# AMHCU.
# Stock_CSV/AMHCU.csv
# TCCO.csv
# TCCO.
# Stock_CSV/TCCO.csv
# PKOH 2.csv
# PKOH 2.
# Stock_CSV/PKOH 2.csv
# CNTG.csv
# CNTG.
# Stock_CSV/CNTG.csv
# TCBK.csv
# TCBK.
# Stock_CSV/TCBK.csv
# LCAHU.csv
# LCAHU.
# Stock_CSV/LCAHU.csv
# FORK.csv
# FORK.
# Stock_CSV/FORK.csv
# QNST.csv
# QNST.
# Stock_CSV/QNST.csv
# GILT.csv
# GILT.
# Stock_CSV/GILT.csv
# ULTA.csv
# ULTA.
# Stock_CSV/ULTA.csv
# GLPI.csv
# GLPI.
# Stock_CSV/GLPI.csv
# VRCA.csv
# VRCA.
# Stock_CSV/VRCA.csv
# VC.csv
# VC.
# Stock_CSV/VC.csv
# PDSB 2.csv
# PDSB 2.
# Stock_CSV/PDSB 2.csv
# CIZ.csv
# CIZ.
# Stock_CSV/CIZ.csv
# MGI.csv
# MGI.
# Stock_CSV/MGI.csv
# MEDS.csv
# MEDS.
# Stock_CSV/MEDS.csv
# FTC.csv
# FTC.
# Stock_CSV/FTC.csv
# FSBW.csv
# FSBW.
# Stock_CSV/FSBW.csv
# THRM.csv
# THRM.
# Stock_CSV/THRM.csv
# CYCC.csv
# CYCC.
# Stock_CSV/CYCC.csv
# PRTK 2.csv
# PRTK 2.
# Stock_CSV/PRTK 2.csv
# NEON.csv
# NEON.
# Stock_CSV/NEON.csv
# TROW 2.csv
# TROW 2.
# Stock_CSV/TROW 2.csv
# DEACU.csv
# DEACU.
# Stock_CSV/DEACU.csv
# AQMS.csv
# AQMS.
# Stock_CSV/AQMS.csv
# BOXL.csv
# BOXL.
# Stock_CSV/BOXL.csv
# PBPB 2.csv
# PBPB 2.
# Stock_CSV/PBPB 2.csv
# OSUR.csv
# OSUR.
# Stock_CSV/OSUR.csv
# SOLOW 2.csv
# SOLOW 2.
# Stock_CSV/SOLOW 2.csv
# HCSG.csv
# HCSG.
# Stock_CSV/HCSG.csv
# PDLB.csv
# PDLB.
# Stock_CSV/PDLB.csv
# BSJO.csv
# BSJO.
# Stock_CSV/BSJO.csv
# CIFS.csv
# CIFS.
# Stock_CSV/CIFS.csv
# AXGN.csv
# AXGN.
# Stock_CSV/AXGN.csv
# FAB.csv
# FAB.
# Stock_CSV/FAB.csv
# FDUS.csv
# FDUS.
# Stock_CSV/FDUS.csv
# TXMD.csv
# TXMD.
# Stock_CSV/TXMD.csv
# INSU.csv
# INSU.
# Stock_CSV/INSU.csv
# SLS 2.csv
# SLS 2.
# Stock_CSV/SLS 2.csv
# QRTEA.csv
# QRTEA.
# Stock_CSV/QRTEA.csv
# SHV 2.csv
# SHV 2.
# Stock_CSV/SHV 2.csv
# WTFC.csv
# WTFC.
# Stock_CSV/WTFC.csv
# TFFP.csv
# TFFP.
# Stock_CSV/TFFP.csv
# BRPAW.csv
# BRPAW.
# Stock_CSV/BRPAW.csv
# BDGE.csv
# BDGE.
# Stock_CSV/BDGE.csv
# RTTR 2.csv
# RTTR 2.
# Stock_CSV/RTTR 2.csv
# RBCN.csv
# RBCN.
# Stock_CSV/RBCN.csv
# GBDC.csv
# GBDC.
# Stock_CSV/GBDC.csv
# LAZY.csv
# LAZY.
# Stock_CSV/LAZY.csv
# GHIVU.csv
# GHIVU.
# Stock_CSV/GHIVU.csv
# DPHCU.csv
# DPHCU.
# Stock_CSV/DPHCU.csv
# DWCR.csv
# DWCR.
# Stock_CSV/DWCR.csv
# ODP.csv
# ODP.
# Stock_CSV/ODP.csv
# UBCP.csv
# UBCP.
# Stock_CSV/UBCP.csv
# MRCCL 2.csv
# MRCCL 2.
# Stock_CSV/MRCCL 2.csv
# PEP.csv
# PEP.
# Stock_CSV/PEP.csv
# IFRX.csv
# IFRX.
# Stock_CSV/IFRX.csv
# FDUSZ.csv
# FDUSZ.
# Stock_CSV/FDUSZ.csv
# TGLS.csv
# TGLS.
# Stock_CSV/TGLS.csv
# NSIT.csv
# NSIT.
# Stock_CSV/NSIT.csv
# CHPMU.csv
# CHPMU.
# Stock_CSV/CHPMU.csv
# IMBI.csv
# IMBI.
# Stock_CSV/IMBI.csv
# AERI.csv
# AERI.
# Stock_CSV/AERI.csv
# MOFG.csv
# MOFG.
# Stock_CSV/MOFG.csv
# FNCB.csv
# FNCB.
# Stock_CSV/FNCB.csv
# RARE.csv
# RARE.
# Stock_CSV/RARE.csv
# DAKT.csv
# DAKT.
# Stock_CSV/DAKT.csv
# SNDX.csv
# SNDX.
# Stock_CSV/SNDX.csv
# ONCY.csv
# ONCY.
# Stock_CSV/ONCY.csv
# ABTX.csv
# ABTX.
# Stock_CSV/ABTX.csv
# ANAT.csv
# ANAT.
# Stock_CSV/ANAT.csv
# SRTS.csv
# SRTS.
# Stock_CSV/SRTS.csv
# COKE.csv
# COKE.
# Stock_CSV/COKE.csv
# SANM 2.csv
# SANM 2.
# Stock_CSV/SANM 2.csv
# PRSC 2.csv
# PRSC 2.
# Stock_CSV/PRSC 2.csv
# NFINU.csv
# NFINU.
# Stock_CSV/NFINU.csv
# OLED 2.csv
# OLED 2.
# Stock_CSV/OLED 2.csv
# REGI 2.csv
# REGI 2.
# Stock_CSV/REGI 2.csv
# PID.csv
# PID.
# Stock_CSV/PID.csv
# RPD.csv
# RPD.
# Stock_CSV/RPD.csv
# EYPT.csv
# EYPT.
# Stock_CSV/EYPT.csv
# XONE.csv
# XONE.
# Stock_CSV/XONE.csv
# APEX.csv
# APEX.
# Stock_CSV/APEX.csv
# GMLP.csv
# GMLP.
# Stock_CSV/GMLP.csv
# GCBC.csv
# GCBC.
# Stock_CSV/GCBC.csv
# SG 2.csv
# SG 2.
# Stock_CSV/SG 2.csv
# FRHC.csv
# FRHC.
# Stock_CSV/FRHC.csv
# MJCO.csv
# MJCO.
# Stock_CSV/MJCO.csv
# QQQX.csv
# QQQX.
# Stock_CSV/QQQX.csv
# APPN.csv
# APPN.
# Stock_CSV/APPN.csv
# LLY.csv
# LLY.
# Stock_CSV/LLY.csv
# LOB.csv
# LOB.
# Stock_CSV/LOB.csv
# PRQR.csv
# PRQR.
# Stock_CSV/PRQR.csv
# FPRX.csv
# FPRX.
# Stock_CSV/FPRX.csv
# NGHCZ.csv
# NGHCZ.
# Stock_CSV/NGHCZ.csv
# PBIP 2.csv
# PBIP 2.
# Stock_CSV/PBIP 2.csv
# PSTVZ.csv
# PSTVZ.
# Stock_CSV/PSTVZ.csv
# FBMS.csv
# FBMS.
# Stock_CSV/FBMS.csv
# NHLDW.csv
# NHLDW.
# Stock_CSV/NHLDW.csv
# OPRT.csv
# OPRT.
# Stock_CSV/OPRT.csv
# NTAP 2.csv
# NTAP 2.
# Stock_CSV/NTAP 2.csv
# MASI.csv
# MASI.
# Stock_CSV/MASI.csv
# MSON.csv
# MSON.
# Stock_CSV/MSON.csv
# TPTX.csv
# TPTX.
# Stock_CSV/TPTX.csv
# ONVO.csv
# ONVO.
# Stock_CSV/ONVO.csv
# EGAN.csv
# EGAN.
# Stock_CSV/EGAN.csv
# LCA.csv
# LCA.
# Stock_CSV/LCA.csv
# MCEF.csv
# MCEF.
# Stock_CSV/MCEF.csv
# ALNY.csv
# ALNY.
# Stock_CSV/ALNY.csv
# FISI.csv
# FISI.
# Stock_CSV/FISI.csv
# MSBI.csv
# MSBI.
# Stock_CSV/MSBI.csv
# BIOC.csv
# BIOC.
# Stock_CSV/BIOC.csv
# NEOG 2.csv
# NEOG 2.
# Stock_CSV/NEOG 2.csv
# COST.csv
# COST.
# Stock_CSV/COST.csv
# TEAM 2.csv
# TEAM 2.
# Stock_CSV/TEAM 2.csv
# WWD.csv
# WWD.
# Stock_CSV/WWD.csv
# RILYN 2.csv
# RILYN 2.
# Stock_CSV/RILYN 2.csv
# STSA 2.csv
# STSA 2.
# Stock_CSV/STSA 2.csv
# VSEC.csv
# VSEC.
# Stock_CSV/VSEC.csv
# BLRX.csv
# BLRX.
# Stock_CSV/BLRX.csv
# IFGL.csv
# IFGL.
# Stock_CSV/IFGL.csv
# PPD.csv
# PPD.
# Stock_CSV/PPD.csv
# NYMX 2.csv
# NYMX 2.
# Stock_CSV/NYMX 2.csv
# FREQ.csv
# FREQ.
# Stock_CSV/FREQ.csv
# MDGSW.csv
# MDGSW.
# Stock_CSV/MDGSW.csv
# SBAC 2.csv
# SBAC 2.
# Stock_CSV/SBAC 2.csv
# GABC.csv
# GABC.
# Stock_CSV/GABC.csv
# PNNT.csv
# PNNT.
# Stock_CSV/PNNT.csv
# SITM 2.csv
# SITM 2.
# Stock_CSV/SITM 2.csv
# BIMI.csv
# BIMI.
# Stock_CSV/BIMI.csv
# SNSS.csv
# SNSS.
# Stock_CSV/SNSS.csv
# RECN 2.csv
# RECN 2.
# Stock_CSV/RECN 2.csv
# SYPR.csv
# SYPR.
# Stock_CSV/SYPR.csv
# TBLT 2.csv
# TBLT 2.
# Stock_CSV/TBLT 2.csv
# CORE.csv
# CORE.
# Stock_CSV/CORE.csv
# QCLN.csv
# QCLN.
# Stock_CSV/QCLN.csv
# OBLN.csv
# OBLN.
# Stock_CSV/OBLN.csv
# REG.csv
# REG.
# Stock_CSV/REG.csv
# LSACU.csv
# LSACU.
# Stock_CSV/LSACU.csv
# NGHCO.csv
# NGHCO.
# Stock_CSV/NGHCO.csv
# ALBO.csv
# ALBO.
# Stock_CSV/ALBO.csv
# VCNX.csv
# VCNX.
# Stock_CSV/VCNX.csv
# SPWH.csv
# SPWH.
# Stock_CSV/SPWH.csv
# NWS.csv
# NWS.
# Stock_CSV/NWS.csv
# CASY.csv
# CASY.
# Stock_CSV/CASY.csv
# LOW.csv
# LOW.
# Stock_CSV/LOW.csv
# AEHR.csv
# AEHR.
# Stock_CSV/AEHR.csv
# OPRA.csv
