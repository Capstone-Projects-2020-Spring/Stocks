# %%
#Install the dependencies
import numpy as np 
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib. pyplot as plt

# %%
# Storing FB stock data into our dataframe df

# empty list
moving_avg = []

# interval we want to take the average from
interval = 5

stock_list = ['FB','AAPL']
for stock in stock_list:
    print(stock)
    df = pd.read_csv("stock_csv_avg_test/" + stock + '.csv') 
    df= df[['4. close']]
    closing_prices = df.iloc[0:30].values
    len_prices = len(closing_prices)
    
    for i in range(len_prices):  
        if i==(len_prices-interval-1):
            break
        sum_prices = 0 
        
        for j in range(interval): 
            print(closing_prices[i+j])
            sum_prices += closing_prices[i+j]
        
        moving_avg.append(sum_prices/interval) 
        print('sum:',sum_prices)
        #print('\n') 
        print('moving avg:',moving_avg)
        print('\n')
    
    #lst = lst[:len(lst)-n]
    # only keeping first n - interval rows for the graph - same amount of days match 
    delete_intvl = closing_prices[:len(closing_prices)-interval]
    print(delete_intvl)
    
    plt.plot(moving_avg)
    plt.plot(delete_intvl)
    plt.title('Moving Average Mirror for '+ stock)
    plt.xlabel('Days')
    plt.ylabel('Prices')
    plt.savefig('../Stocks/Stock_Plot/' + stock + '.png')
   
    
    moving_avg.clear()
# Out:
# FB
# [156.79]
# [163.34]
# [156.21]
# [160.98]
# [148.1]
# sum: [785.42]
# moving avg: [array([157.084])]
#
#
# [163.34]
# [156.21]
# [160.98]
# [148.1]
# [149.73]
# sum: [778.36]
# moving avg: [array([157.084]), array([155.672])]
#
#
# [156.21]
# [160.98]
# [148.1]
# [149.73]
# [153.13]
# sum: [768.15]
# moving avg: [array([157.084]), array([155.672]), array([153.63])]
#
#
# [160.98]
# [148.1]
# [149.73]
# [153.13]
# [146.96]
# sum: [758.9]
# moving avg: [array([157.084]), array([155.672]), array([153.63]), array([151.78])]
#
#
# [148.1]
# [149.73]
# [153.13]
# [146.96]
# [149.42]
# sum: [747.34]
# moving avg: [array([157.084]), array([155.672]), array([153.63]), array([151.78]), array([149.468])]
#
#
# [149.73]
# [153.13]
# [146.96]
# [149.42]
# [146.01]
# sum: [745.25]
# moving avg: [array([157.084]), array([155.672]), array([153.63]), array([151.78]), array([149.468]), array([149.05])]
#
#
# [153.13]
# [146.96]
# [149.42]
# [146.01]
# [170.28]
# sum: [765.8]
# moving avg: [array([157.084]), array([155.672]), array([153.63]), array([151.78]), array([149.468]), array([149.05]), array([153.16])]
#
#
# [146.96]
# [149.42]
# [146.01]
# [170.28]
# [154.47]
# sum: [767.14]
# moving avg: [array([157.084]), array([155.672]), array([153.63]), array([151.78]), array([149.468]), array([149.05]), array([153.16]), array([153.428])]
#
#
# [149.42]
# [146.01]
# [170.28]
# [154.47]
# [170.24]
# sum: [790.42]
# moving avg: [array([157.084]), array([155.672]), array([153.63]), array([151.78]), array([149.468]), array([149.05]), array([153.16]), array([153.428]), array([158.084])]
#
#
# [146.01]
# [170.28]
# [154.47]
# [170.24]
# [178.19]
# sum: [819.19]
# moving avg: [array([157.084]), array([155.672]), array([153.63]), array([151.78]), array([149.468]), array([149.05]), array([153.16]), array([153.428]), array([158.084]), array([163.838])]
#
#
# [170.28]
# [154.47]
# [170.24]
# [178.19]
# [169.5]
# sum: [842.68]
# moving avg: [array([157.084]), array([155.672]), array([153.63]), array([151.78]), array([149.468]), array([149.05]), array([153.16]), array([153.428]), array([158.084]), array([163.838]), array([168.536])]
#
#
# [154.47]
# [170.24]
# [178.19]
# [169.5]
# [181.09]
# sum: [853.49]
# moving avg: [array([157.084]), array([155.672]), array([153.63]), array([151.78]), array([149.468]), array([149.05]), array([153.16]), array([153.428]), array([158.084]), array([163.838]), array([168.536]), array([170.698])]
#
#
# [170.24]
# [178.19]
# [169.5]
# [181.09]
# [185.17]
# sum: [884.19]
# moving avg: [array([157.084]), array([155.672]), array([153.63]), array([151.78]), array([149.468]), array([149.05]), array([153.16]), array([153.428]), array([158.084]), array([163.838]), array([168.536]), array([170.698]), array([176.838])]
#
#
# [178.19]
# [169.5]
# [181.09]
# [185.17]
# [191.76]
# sum: [905.71]
# moving avg: [array([157.084]), array([155.672]), array([153.63]), array([151.78]), array([149.468]), array([149.05]), array([153.16]), array([153.428]), array([158.084]), array([163.838]), array([168.536]), array([170.698]), array([176.838]), array([181.142])]
#
#
# [169.5]
# [181.09]
# [185.17]
# [191.76]
# [185.89]
# sum: [913.41]
# moving avg: [array([157.084]), array([155.672]), array([153.63]), array([151.78]), array([149.468]), array([149.05]), array([153.16]), array([153.428]), array([158.084]), array([163.838]), array([168.536]), array([170.698]), array([176.838]), array([181.142]), array([182.682])]
#
#
# [181.09]
# [185.17]
# [191.76]
# [185.89]
# [196.44]
# sum: [940.35]
# moving avg: [array([157.084]), array([155.672]), array([153.63]), array([151.78]), array([149.468]), array([149.05]), array([153.16]), array([153.428]), array([158.084]), array([163.838]), array([168.536]), array([170.698]), array([176.838]), array([181.142]), array([182.682]), array([188.07])]
#
#
# [185.17]
# [191.76]
# [185.89]
# [196.44]
# [192.47]
# sum: [951.73]
# moving avg: [array([157.084]), array([155.672]), array([153.63]), array([151.78]), array([149.468]), array([149.05]), array([153.16]), array([153.428]), array([158.084]), array([163.838]), array([168.536]), array([170.698]), array([176.838]), array([181.142]), array([182.682]), array([188.07]), array([190.346])]
#
#
# [191.76]
# [185.89]
# [196.44]
# [192.47]
# [189.75]
# sum: [956.31]
# moving avg: [array([157.084]), array([155.672]), array([153.63]), array([151.78]), array([149.468]), array([149.05]), array([153.16]), array([153.428]), array([158.084]), array([163.838]), array([168.536]), array([170.698]), array([176.838]), array([181.142]), array([182.682]), array([188.07]), array([190.346]), array([191.262])]
#
#
# [185.89]
# [196.44]
# [192.47]
# [189.75]
# [197.2]
# sum: [961.75]
# moving avg: [array([157.084]), array([155.672]), array([153.63]), array([151.78]), array([149.468]), array([149.05]), array([153.16]), array([153.428]), array([158.084]), array([163.838]), array([168.536]), array([170.698]), array([176.838]), array([181.142]), array([182.682]), array([188.07]), array([190.346]), array([191.262]), array([192.35])]
#
#
# [196.44]
# [192.47]
# [189.75]
# [197.2]
# [196.77]
# sum: [972.63]
# moving avg: [array([157.084]), array([155.672]), array([153.63]), array([151.78]), array([149.468]), array([149.05]), array([153.16]), array([153.428]), array([158.084]), array([163.838]), array([168.536]), array([170.698]), array([176.838]), array([181.142]), array([182.682]), array([188.07]), array([190.346]), array([191.262]), array([192.35]), array([194.526])]
#
#
# [192.47]
# [189.75]
# [197.2]
# [196.77]
# [200.72]
# sum: [976.91]
# moving avg: [array([157.084]), array([155.672]), array([153.63]), array([151.78]), array([149.468]), array([149.05]), array([153.16]), array([153.428]), array([158.084]), array([163.838]), array([168.536]), array([170.698]), array([176.838]), array([181.142]), array([182.682]), array([188.07]), array([190.346]), array([191.262]), array([192.35]), array([194.526]), array([195.382])]
#
#
# [189.75]
# [197.2]
# [196.77]
# [200.72]
# [210.18]
# sum: [994.62]
# moving avg: [array([157.084]), array([155.672]), array([153.63]), array([151.78]), array([149.468]), array([149.05]), array([153.16]), array([153.428]), array([158.084]), array([163.838]), array([168.536]), array([170.698]), array([176.838]), array([181.142]), array([182.682]), array([188.07]), array([190.346]), array([191.262]), array([192.35]), array([194.526]), array([195.382]), array([198.924])]
#
#
# [197.2]
# [196.77]
# [200.72]
# [210.18]
# [214.58]
# sum: [1019.45]
# moving avg: [array([157.084]), array([155.672]), array([153.63]), array([151.78]), array([149.468]), array([149.05]), array([153.16]), array([153.428]), array([158.084]), array([163.838]), array([168.536]), array([170.698]), array([176.838]), array([181.142]), array([182.682]), array([188.07]), array([190.346]), array([191.262]), array([192.35]), array([194.526]), array([195.382]), array([198.924]), array([203.89])]
#
#
# [196.77]
# [200.72]
# [210.18]
# [214.58]
# [217.49]
# sum: [1039.74]
# moving avg: [array([157.084]), array([155.672]), array([153.63]), array([151.78]), array([149.468]), array([149.05]), array([153.16]), array([153.428]), array([158.084]), array([163.838]), array([168.536]), array([170.698]), array([176.838]), array([181.142]), array([182.682]), array([188.07]), array([190.346]), array([191.262]), array([192.35]), array([194.526]), array([195.382]), array([198.924]), array([203.89]), array([207.948])]
#
#
# [[156.79]
#  [163.34]
#  [156.21]
#  [160.98]
#  [148.1 ]
#  [149.73]
#  [153.13]
#  [146.96]
#  [149.42]
#  [146.01]
#  [170.28]
#  [154.47]
#  [170.24]
#  [178.19]
#  [169.5 ]
#  [181.09]
#  [185.17]
#  [191.76]
#  [185.89]
#  [196.44]
#  [192.47]
#  [189.75]
#  [197.2 ]
#  [196.77]
#  [200.72]]
# AAPL
# [247.74]
# [258.44]
# [245.52]
# [246.88]
# [224.37]
# sum: [1222.95]
# moving avg: [array([244.59])]
#
#
# [258.44]
# [245.52]
# [246.88]
# [224.37]
# [229.24]
# sum: [1204.45]
# moving avg: [array([244.59]), array([240.89])]
#
#
# [245.52]
# [246.88]
# [224.37]
# [229.24]
# [244.78]
# sum: [1190.79]
# moving avg: [array([244.59]), array([240.89]), array([238.158])]
#
#
# [246.88]
# [224.37]
# [229.24]
# [244.78]
# [246.67]
# sum: [1191.94]
# moving avg: [array([244.59]), array([240.89]), array([238.158]), array([238.388])]
#
#
# [224.37]
# [229.24]
# [244.78]
# [246.67]
# [252.86]
# sum: [1197.92]
# moving avg: [array([244.59]), array([240.89]), array([238.158]), array([238.388]), array([239.584])]
#
#
# [229.24]
# [244.78]
# [246.67]
# [252.86]
# [242.21]
# sum: [1215.76]
# moving avg: [array([244.59]), array([240.89]), array([238.158]), array([238.388]), array([239.584]), array([243.152])]
#
#
# [244.78]
# [246.67]
# [252.86]
# [242.21]
# [277.97]
# sum: [1264.49]
# moving avg: [array([244.59]), array([240.89]), array([238.158]), array([238.388]), array([239.584]), array([243.152]), array([252.898])]
#
#
# [246.67]
# [252.86]
# [242.21]
# [277.97]
# [248.23]
# sum: [1267.94]
# moving avg: [array([244.59]), array([240.89]), array([238.158]), array([238.388]), array([239.584]), array([243.152]), array([252.898]), array([253.588])]
#
#
# [252.86]
# [242.21]
# [277.97]
# [248.23]
# [275.43]
# sum: [1296.7]
# moving avg: [array([244.59]), array([240.89]), array([238.158]), array([238.388]), array([239.584]), array([243.152]), array([252.898]), array([253.588]), array([259.34])]
#
#
# [242.21]
# [277.97]
# [248.23]
# [275.43]
# [285.34]
# sum: [1329.18]
# moving avg: [array([244.59]), array([240.89]), array([238.158]), array([238.388]), array([239.584]), array([243.152]), array([252.898]), array([253.588]), array([259.34]), array([265.836])]
#
#
# [277.97]
# [248.23]
# [275.43]
# [285.34]
# [266.17]
# sum: [1353.14]
# moving avg: [array([244.59]), array([240.89]), array([238.158]), array([238.388]), array([239.584]), array([243.152]), array([252.898]), array([253.588]), array([259.34]), array([265.836]), array([270.628])]
#
#
# [248.23]
# [275.43]
# [285.34]
# [266.17]
# [289.03]
# sum: [1364.2]
# moving avg: [array([244.59]), array([240.89]), array([238.158]), array([238.388]), array([239.584]), array([243.152]), array([252.898]), array([253.588]), array([259.34]), array([265.836]), array([270.628]), array([272.84])]
#
#
# [275.43]
# [285.34]
# [266.17]
# [289.03]
# [292.92]
# sum: [1408.89]
# moving avg: [array([244.59]), array([240.89]), array([238.158]), array([238.388]), array([239.584]), array([243.152]), array([252.898]), array([253.588]), array([259.34]), array([265.836]), array([270.628]), array([272.84]), array([281.778])]
#
#
# [285.34]
# [266.17]
# [289.03]
# [292.92]
# [302.74]
# sum: [1436.2]
# moving avg: [array([244.59]), array([240.89]), array([238.158]), array([238.388]), array([239.584]), array([243.152]), array([252.898]), array([253.588]), array([259.34]), array([265.836]), array([270.628]), array([272.84]), array([281.778]), array([287.24])]
#
#
# [266.17]
# [289.03]
# [292.92]
# [302.74]
# [289.32]
# sum: [1440.18]
# moving avg: [array([244.59]), array([240.89]), array([238.158]), array([238.388]), array([239.584]), array([243.152]), array([252.898]), array([253.588]), array([259.34]), array([265.836]), array([270.628]), array([272.84]), array([281.778]), array([287.24]), array([288.036])]
#
#
# [289.03]
# [292.92]
# [302.74]
# [289.32]
# [298.81]
# sum: [1472.82]
# moving avg: [array([244.59]), array([240.89]), array([238.158]), array([238.388]), array([239.584]), array([243.152]), array([252.898]), array([253.588]), array([259.34]), array([265.836]), array([270.628]), array([272.84]), array([281.778]), array([287.24]), array([288.036]), array([294.564])]
#
#
# [292.92]
# [302.74]
# [289.32]
# [298.81]
# [273.36]
# sum: [1457.15]
# moving avg: [array([244.59]), array([240.89]), array([238.158]), array([238.388]), array([239.584]), array([243.152]), array([252.898]), array([253.588]), array([259.34]), array([265.836]), array([270.628]), array([272.84]), array([281.778]), array([287.24]), array([288.036]), array([294.564]), array([291.43])]
#
#
# [302.74]
# [289.32]
# [298.81]
# [273.36]
# [273.52]
# sum: [1437.75]
# moving avg: [array([244.59]), array([240.89]), array([238.158]), array([238.388]), array([239.584]), array([243.152]), array([252.898]), array([253.588]), array([259.34]), array([265.836]), array([270.628]), array([272.84]), array([281.778]), array([287.24]), array([288.036]), array([294.564]), array([291.43]), array([287.55])]
#
#
# [289.32]
# [298.81]
# [273.36]
# [273.52]
# [292.65]
# sum: [1427.66]
# moving avg: [array([244.59]), array([240.89]), array([238.158]), array([238.388]), array([239.584]), array([243.152]), array([252.898]), array([253.588]), array([259.34]), array([265.836]), array([270.628]), array([272.84]), array([281.778]), array([287.24]), array([288.036]), array([294.564]), array([291.43]), array([287.55]), array([285.532])]
#
#
# [298.81]
# [273.36]
# [273.52]
# [292.65]
# [288.08]
# sum: [1426.42]
# moving avg: [array([244.59]), array([240.89]), array([238.158]), array([238.388]), array([239.584]), array([243.152]), array([252.898]), array([253.588]), array([259.34]), array([265.836]), array([270.628]), array([272.84]), array([281.778]), array([287.24]), array([288.036]), array([294.564]), array([291.43]), array([287.55]), array([285.532]), array([285.284])]
#
#
# [273.36]
# [273.52]
# [292.65]
# [288.08]
# [298.18]
# sum: [1425.79]
# moving avg: [array([244.59]), array([240.89]), array([238.158]), array([238.388]), array([239.584]), array([243.152]), array([252.898]), array([253.588]), array([259.34]), array([265.836]), array([270.628]), array([272.84]), array([281.778]), array([287.24]), array([288.036]), array([294.564]), array([291.43]), array([287.55]), array([285.532]), array([285.284]), array([285.158])]
#
#
# [273.52]
# [292.65]
# [288.08]
# [298.18]
# [313.05]
# sum: [1465.48]
# moving avg: [array([244.59]), array([240.89]), array([238.158]), array([238.388]), array([239.584]), array([243.152]), array([252.898]), array([253.588]), array([259.34]), array([265.836]), array([270.628]), array([272.84]), array([281.778]), array([287.24]), array([288.036]), array([294.564]), array([291.43]), array([287.55]), array([285.532]), array([285.284]), array([285.158]), array([293.096])]
#
#
# [292.65]
# [288.08]
# [298.18]
# [313.05]
# [320.3]
# sum: [1512.26]
# moving avg: [array([244.59]), array([240.89]), array([238.158]), array([238.388]), array([239.584]), array([243.152]), array([252.898]), array([253.588]), array([259.34]), array([265.836]), array([270.628]), array([272.84]), array([281.778]), array([287.24]), array([288.036]), array([294.564]), array([291.43]), array([287.55]), array([285.532]), array([285.284]), array([285.158]), array([293.096]), array([302.452])]
#
#
# [288.08]
# [298.18]
# [313.05]
# [320.3]
# [323.62]
# sum: [1543.23]
# moving avg: [array([244.59]), array([240.89]), array([238.158]), array([238.388]), array([239.584]), array([243.152]), array([252.898]), array([253.588]), array([259.34]), array([265.836]), array([270.628]), array([272.84]), array([281.778]), array([287.24]), array([288.036]), array([294.564]), array([291.43]), array([287.55]), array([285.532]), array([285.284]), array([285.158]), array([293.096]), array([302.452]), array([308.646])]
#
#
# [[247.74]
#  [258.44]
#  [245.52]
#  [246.88]
#  [224.37]
#  [229.24]
#  [244.78]
#  [246.67]
#  [252.86]
#  [242.21]
#  [277.97]
#  [248.23]
#  [275.43]
#  [285.34]
#  [266.17]
#  [289.03]
#  [292.92]
#  [302.74]
#  [289.32]
#  [298.81]
#  [273.36]
#  [273.52]
#  [292.65]
#  [288.08]
#  [298.18]]
