# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import neighbors
from sklearn.model_selection import train_test_split
import matplotlib as mpl # this actually imports matplotlib
import matplotlib.cm as cm #allows us easy access to colormaps
import matplotlib.pyplot as plt #sets up plotting under plt
import pandas as pd #lets us handle data as dataframes
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.models import Sequential
from sklearn.linear_model import LinearRegression
import time
from numpy import newaxis
import warnings
warnings.filterwarnings("ignore") #Hide messy Numpy warnings
# Out:
# Using TensorFlow backend.

# %%
raw_df = pd.read_csv("../Stocks/Stock_CSV/FB.csv")

# %%
raw_seq = raw_df["4. close"]

# %%
seq = [ele for ele in reversed(raw_seq)] 
seq = np.array(seq)
seq.shape
plt.plot(seq[1800:])

# %%
x =7
seq_len = 50
sequence_length = seq_len + 1
result = []
for index in range(len(seq) - sequence_length):
    result.append(seq[index: index + sequence_length])
    
result = normalise_windows(result)

result = np.array(result)

row = round(0.9 * len(result))
train = result[:int(row), :]
np.random.shuffle(train)
x_train = train[:, :-1]
y_train = train[:, -1]
x_test = result[int(row):, :-1]
y_test = result[int(row):, -1]

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))  

result.shape
# Out:
# (1926, 51)

# %%
def normalise_windows(window_data):
    normalised_data = []
    for window in window_data:
        normalised_window = [((float(p) / float(window[0])) - 1) for p in window]
        normalised_data.append(normalised_window)
    return normalised_data

# %%
def build_model(layers):
    model = Sequential()

    model.add(LSTM(
        input_dim=layers[0],
        output_dim=layers[1],
        return_sequences=True))
    model.add(Dropout(0.2))

    model.add(LSTM(
        layers[2],
        return_sequences=False))
    model.add(Dropout(0.2))

    model.add(Dense(
        output_dim=layers[3]))
    model.add(Activation("linear"))

    start = time.time()
    model.compile(loss="mse", optimizer="rmsprop")
    print("> Compilation Time : ", time.time() - start)
    return model

# %%
def predict_point_by_point(model, data):
    #Predict each timestep given the last sequence of true data, in effect only predicting 1 step ahead each time
    predicted = model.predict(data)
    predicted = np.reshape(predicted, (predicted.size,))
    return predicted

# %%
def predict_sequence_full(model, data, window_size):
    #Shift the window by 1 new prediction each time, re-run predictions on new window
    curr_frame = data[0]
    predicted = []
    for i in range(len(data)):
        predicted.append(model.predict(curr_frame[newaxis,:,:])[0,0])
        curr_frame = curr_frame[1:]
        curr_frame = np.insert(curr_frame, [window_size-1], predicted[-1], axis=0)
    return predicted

# %%
def predict_sequences_multiple(model, data, window_size, prediction_len):
    #Predict sequence of 50 steps before shifting prediction run forward by 50 steps
    prediction_seqs = []
    for i in range(int(len(data)/prediction_len)):
        curr_frame = data[i*prediction_len]
        predicted = []
        for j in range(prediction_len):
            predicted.append(model.predict(curr_frame[newaxis,:,:])[0,0])
            curr_frame = curr_frame[1:]
            curr_frame = np.insert(curr_frame, [window_size-1], predicted[-1], axis=0)
        prediction_seqs.append(predicted)
    return prediction_seqs

# %%
def plot_results_multiple(predicted_data, true_data, prediction_len):
    fig = plt.figure(facecolor='white',figsize = (10,10))
    ax = fig.add_subplot(111)
    ax.plot(true_data, label='True Data')
    #Pad the list of predictions to shift it in the graph to it's correct start
    for i, data in enumerate(predicted_data):
        padding = [None for p in range(i * prediction_len)]
        plt.plot(padding + data)
        plt.legend()
    plt.show()

# %%
model = build_model([1,10,20,1])
# Out:
# > Compilation Time :  0.007978439331054688

# %%
epochs = 50
model.fit(
    x_train,
    y_train,
    batch_size = 64,
    nb_epoch=epochs,
    validation_split=0.05)
# Out:
# Train on 1646 samples, validate on 87 samples
# Epoch 1/50
# 1646/1646 [==============================] - 2s 1ms/step - loss: 0.0071 - val_loss: 0.0033
# Epoch 2/50
# 1646/1646 [==============================] - 1s 740us/step - loss: 0.0043 - val_loss: 0.0029
# Epoch 3/50
# 1646/1646 [==============================] - 1s 756us/step - loss: 0.0037 - val_loss: 0.0022
# Epoch 4/50
# 1646/1646 [==============================] - 1s 744us/step - loss: 0.0034 - val_loss: 0.0018
# Epoch 5/50
# 1646/1646 [==============================] - 1s 748us/step - loss: 0.0030 - val_loss: 0.0017
# Epoch 6/50
# 1646/1646 [==============================] - 1s 758us/step - loss: 0.0030 - val_loss: 0.0015
# Epoch 7/50
# 1646/1646 [==============================] - 1s 741us/step - loss: 0.0028 - val_loss: 0.0014
# Epoch 8/50
# 1646/1646 [==============================] - 1s 732us/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 9/50
# 1646/1646 [==============================] - 1s 749us/step - loss: 0.0026 - val_loss: 0.0015
# Epoch 10/50
# 1646/1646 [==============================] - 1s 750us/step - loss: 0.0025 - val_loss: 0.0011
# Epoch 11/50
# 1646/1646 [==============================] - 1s 753us/step - loss: 0.0024 - val_loss: 0.0011
# Epoch 12/50
# 1646/1646 [==============================] - 1s 739us/step - loss: 0.0025 - val_loss: 0.0010
# Epoch 13/50
# 1646/1646 [==============================] - 1s 751us/step - loss: 0.0024 - val_loss: 0.0011
# Epoch 14/50
# 1646/1646 [==============================] - 1s 745us/step - loss: 0.0022 - val_loss: 9.7441e-04
# Epoch 15/50
# 1646/1646 [==============================] - 1s 751us/step - loss: 0.0025 - val_loss: 0.0013
# Epoch 16/50
# 1646/1646 [==============================] - 1s 750us/step - loss: 0.0023 - val_loss: 9.1540e-04
# Epoch 17/50
# 1646/1646 [==============================] - 1s 764us/step - loss: 0.0022 - val_loss: 9.2438e-04
# Epoch 18/50
# 1646/1646 [==============================] - 1s 769us/step - loss: 0.0022 - val_loss: 9.0004e-04
# Epoch 19/50
# 1646/1646 [==============================] - 1s 754us/step - loss: 0.0022 - val_loss: 8.7684e-04
# Epoch 20/50
# 1646/1646 [==============================] - 1s 759us/step - loss: 0.0022 - val_loss: 8.5013e-04
# Epoch 21/50
# 1646/1646 [==============================] - 1s 756us/step - loss: 0.0021 - val_loss: 8.0088e-04
# Epoch 22/50
# 1646/1646 [==============================] - 1s 757us/step - loss: 0.0020 - val_loss: 7.6618e-04
# Epoch 23/50
# 1646/1646 [==============================] - 1s 756us/step - loss: 0.0021 - val_loss: 8.6113e-04
# Epoch 24/50
# 1646/1646 [==============================] - 1s 763us/step - loss: 0.0020 - val_loss: 7.9358e-04
# Epoch 25/50
# 1646/1646 [==============================] - 1s 739us/step - loss: 0.0019 - val_loss: 7.5137e-04
# Epoch 26/50
# 1646/1646 [==============================] - 1s 762us/step - loss: 0.0020 - val_loss: 6.9553e-04
# Epoch 27/50
# 1646/1646 [==============================] - 1s 742us/step - loss: 0.0020 - val_loss: 8.6959e-04
# Epoch 28/50
# 1646/1646 [==============================] - 1s 757us/step - loss: 0.0019 - val_loss: 8.7230e-04
# Epoch 29/50
# 1646/1646 [==============================] - 1s 741us/step - loss: 0.0020 - val_loss: 7.4825e-04
# Epoch 30/50
# 1646/1646 [==============================] - 1s 745us/step - loss: 0.0020 - val_loss: 6.4812e-04
# Epoch 31/50
# 1646/1646 [==============================] - 1s 753us/step - loss: 0.0018 - val_loss: 6.9874e-04
# Epoch 32/50
# 1646/1646 [==============================] - 1s 751us/step - loss: 0.0019 - val_loss: 7.3856e-04
# Epoch 33/50
# 1646/1646 [==============================] - 1s 739us/step - loss: 0.0019 - val_loss: 7.8770e-04
# Epoch 34/50
# 1646/1646 [==============================] - 1s 739us/step - loss: 0.0018 - val_loss: 6.1881e-04
# Epoch 35/50
# 1646/1646 [==============================] - 1s 748us/step - loss: 0.0017 - val_loss: 8.8335e-04
# Epoch 36/50
# 1646/1646 [==============================] - 1s 754us/step - loss: 0.0018 - val_loss: 6.3285e-04
# Epoch 37/50
# 1646/1646 [==============================] - 1s 739us/step - loss: 0.0018 - val_loss: 9.0510e-04
# Epoch 38/50
# 1646/1646 [==============================] - 1s 753us/step - loss: 0.0016 - val_loss: 6.1775e-04
# Epoch 39/50
# 1646/1646 [==============================] - 1s 737us/step - loss: 0.0017 - val_loss: 5.6367e-04
# Epoch 40/50
# 1646/1646 [==============================] - 1s 746us/step - loss: 0.0018 - val_loss: 7.4947e-04
# Epoch 41/50
# 1646/1646 [==============================] - 1s 741us/step - loss: 0.0016 - val_loss: 7.4946e-04
# Epoch 42/50
# 1646/1646 [==============================] - 1s 733us/step - loss: 0.0017 - val_loss: 6.2376e-04
# Epoch 43/50
# 1646/1646 [==============================] - 1s 757us/step - loss: 0.0017 - val_loss: 6.5100e-04
# Epoch 44/50
# 1646/1646 [==============================] - 1s 753us/step - loss: 0.0017 - val_loss: 5.3091e-04
# Epoch 45/50
# 1646/1646 [==============================] - 1s 747us/step - loss: 0.0016 - val_loss: 5.5470e-04
# Epoch 46/50
# 1646/1646 [==============================] - 1s 740us/step - loss: 0.0015 - val_loss: 5.4873e-04
# Epoch 47/50
# 1646/1646 [==============================] - 1s 745us/step - loss: 0.0015 - val_loss: 5.1915e-04
# Epoch 48/50
# 1646/1646 [==============================] - 1s 770us/step - loss: 0.0016 - val_loss: 7.6725e-04
# Epoch 49/50
# 1646/1646 [==============================] - 1s 756us/step - loss: 0.0015 - val_loss: 7.4368e-04
# Epoch 50/50
# 1646/1646 [==============================] - 1s 742us/step - loss: 0.0014 - val_loss: 5.1793e-04

# %%
predicted = predict_point_by_point(model, x_test)

# %%
plt.plot(y_test)
plt.plot(predicted)

# %%
predictions = predict_sequences_multiple(model, x_test, seq_len,x)

# %%
plot_results_multiple(predictions, y_test, x) 
#7 day prediction with 50 day sequence length 50 epochs
#hidden layers 10,20

# %%
plot_results_multiple(predictions, y_test, x) 
#7 day prediction with 50 day sequence length 100 epochs
#hidden layers 5,10

# %%
plot_results_multiple(predictions, y_test, x) 
#20 day prediction with 50 day sequence length 50 epochs
#hidden layers 10,20

# %%
plot_results_multiple(predictions, y_test, x) 
#30 day prediction with 30 day sequence length 125 epochs
#hidden layers 15

# %%
plot_results_multiple(predictions, y_test, x) 
#10 day prediction with 30 day sequence length 50 epochs
#hidden layers 15

# %%
plot_results_multiple(predictions, y_test, x) 
#10 day prediction with 30 day sequence length 100 epochs

# %% [markdown]
# seems to overfit 50 epochs seems to work better

# %%
plot_results_multiple(predictions, y_test, x) 
#10 day prediction with 30 day sequence length 50 epochs

# %%
plot_results_multiple(predictions, y_test, x)
#20 day prediction with 30 day sequence length 50 epochs

# %%
plt.plot(y_test)

# %%
x_test.shape
# Out:
# (193, 50, 1)

# %%
model.predict(x_test[191:])
# Out:
# array([[-0.31189018],
#        [-0.2920789 ]], dtype=float32)
