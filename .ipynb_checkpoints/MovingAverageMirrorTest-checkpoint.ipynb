# %% [markdown]
# # Moving Average Convergence and Divergence for FB Stock

# %%
#Install the dependencies
import numpy as np 
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib. pyplot as plt

# %%
# Storing FB stock data into our dataframe df
df = pd.read_csv("Stock_CSV/FB.csv")

# %%
## showing what the dataframe looks like 
df.head()
# Out:
#          date  1. open  2. high    3. low  4. close   5. volume
# 0  2020-03-27  158.200   160.09  154.7500    156.79  24879869.0
# 1  2020-03-26  158.250   164.00  157.0201    163.34  26579021.0
# 2  2020-03-25  158.920   162.99  153.0600    156.21  35184271.0
# 3  2020-03-24  155.205   161.31  152.5700    160.98  30440369.0
# 4  2020-03-23  149.660   152.31  142.2500    148.10  29830765.0

# %%
## let's take the dataframe df and only take look at '4. close' frame
df= df[['4. close']]

# %%
# Now we just have the closing prices for FB stock
df.head()
# Out:
#    4. close
# 0    156.79
# 1    163.34
# 2    156.21
# 3    160.98
# 4    148.10

# %%
# lets find the Moving Average for the last 30 days.
indextest = df1.iloc[:30]

# %%
# These are all the prices we are looking at
print(indextest)
# Out:
#     4. close
# 0     156.79
# 1     163.34
# 2     156.21
# 3     160.98
# 4     148.10
# 5     149.73
# 6     153.13
# 7     146.96
# 8     149.42
# 9     146.01
# 10    170.28
# 11    154.47
# 12    170.24
# 13    178.19
# 14    169.50
# 15    181.09
# 16    185.17
# 17    191.76
# 18    185.89
# 19    196.44
# 20    192.47
# 21    189.75
# 22    197.20
# 23    196.77
# 24    200.72
# 25    210.18
# 26    214.58
# 27    217.49
# 28    217.80
# 29    214.18

# %%
# Just checking that we get 30 prices
print(len(indextest))
# Out:
# 30

# %%
# converting dataframe df of the first 30 rows to an array, closing_prices
closing_prices = df.iloc[0:30].values
print(closing_prices)
type(closing_prices)

# making sure its array
print(closing_prices[0])

#finding length of array
print(len(closing_prices))
# Out:
# [[156.79]
#  [163.34]
#  [156.21]
#  [160.98]
#  [148.1 ]
#  [149.73]
#  [153.13]
#  [146.96]
#  [149.42]
#  [146.01]
#  [170.28]
#  [154.47]
#  [170.24]
#  [178.19]
#  [169.5 ]
#  [181.09]
#  [185.17]
#  [191.76]
#  [185.89]
#  [196.44]
#  [192.47]
#  [189.75]
#  [197.2 ]
#  [196.77]
#  [200.72]
#  [210.18]
#  [214.58]
#  [217.49]
#  [217.8 ]
#  [214.18]]
# [156.79]
# 30

# %%
# empty list
moving_avg = []

# interval we want to take the average from
interval = 5

# store length of array
len_prices = len(closing_prices)

# %%
# iterate through the prices and find the average of 
for i in range(len_prices):
    if i==(len_prices-interval-1):
        break
    ## summing up prices of intervals
    sum_prices = 0 
    
    for j in range(interval): 
        print(closing_prices[i+j])
        sum_prices += closing_prices[i+j]
        
    ## appending to list averages of intervals
    moving_avg.append(sum_prices/interval) 
    print(sum_prices)
    print('\n')     
            
print(moving_avg)
# Out:
# [156.79]
# [163.34]
# [156.21]
# [160.98]
# [148.1]
# [785.42]
#
#
# [163.34]
# [156.21]
# [160.98]
# [148.1]
# [149.73]
# [778.36]
#
#
# [156.21]
# [160.98]
# [148.1]
# [149.73]
# [153.13]
# [768.15]
#
#
# [160.98]
# [148.1]
# [149.73]
# [153.13]
# [146.96]
# [758.9]
#
#
# [148.1]
# [149.73]
# [153.13]
# [146.96]
# [149.42]
# [747.34]
#
#
# [149.73]
# [153.13]
# [146.96]
# [149.42]
# [146.01]
# [745.25]
#
#
# [153.13]
# [146.96]
# [149.42]
# [146.01]
# [170.28]
# [765.8]
#
#
# [146.96]
# [149.42]
# [146.01]
# [170.28]
# [154.47]
# [767.14]
#
#
# [149.42]
# [146.01]
# [170.28]
# [154.47]
# [170.24]
# [790.42]
#
#
# [146.01]
# [170.28]
# [154.47]
# [170.24]
# [178.19]
# [819.19]
#
#
# [170.28]
# [154.47]
# [170.24]
# [178.19]
# [169.5]
# [842.68]
#
#
# [154.47]
# [170.24]
# [178.19]
# [169.5]
# [181.09]
# [853.49]
#
#
# [170.24]
# [178.19]
# [169.5]
# [181.09]
# [185.17]
# [884.19]
#
#
# [178.19]
# [169.5]
# [181.09]
# [185.17]
# [191.76]
# [905.71]
#
#
# [169.5]
# [181.09]
# [185.17]
# [191.76]
# [185.89]
# [913.41]
#
#
# [181.09]
# [185.17]
# [191.76]
# [185.89]
# [196.44]
# [940.35]
#
#
# [185.17]
# [191.76]
# [185.89]
# [196.44]
# [192.47]
# [951.73]
#
#
# [191.76]
# [185.89]
# [196.44]
# [192.47]
# [189.75]
# [956.31]
#
#
# [185.89]
# [196.44]
# [192.47]
# [189.75]
# [197.2]
# [961.75]
#
#
# [196.44]
# [192.47]
# [189.75]
# [197.2]
# [196.77]
# [972.63]
#
#
# [192.47]
# [189.75]
# [197.2]
# [196.77]
# [200.72]
# [976.91]
#
#
# [189.75]
# [197.2]
# [196.77]
# [200.72]
# [210.18]
# [994.62]
#
#
# [197.2]
# [196.77]
# [200.72]
# [210.18]
# [214.58]
# [1019.45]
#
#
# [196.77]
# [200.72]
# [210.18]
# [214.58]
# [217.49]
# [1039.74]
#
#
# [array([157.084]), array([155.672]), array([153.63]), array([151.78]), array([149.468]), array([149.05]), array([153.16]), array([153.428]), array([158.084]), array([163.838]), array([168.536]), array([170.698]), array([176.838]), array([181.142]), array([182.682]), array([188.07]), array([190.346]), array([191.262]), array([192.35]), array([194.526]), array([195.382]), array([198.924]), array([203.89]), array([207.948])]

# %%
#lst = lst[:len(lst)-n]
# only keeping first n - interval rows for the graph - same amount of days match 
delete_intvl = closing_prices[:len(closing_prices)-interval]
print(delete_intvl)
# Out:
# [[156.79]
#  [163.34]
#  [156.21]
#  [160.98]
#  [148.1 ]
#  [149.73]
#  [153.13]
#  [146.96]
#  [149.42]
#  [146.01]
#  [170.28]
#  [154.47]
#  [170.24]
#  [178.19]
#  [169.5 ]
#  [181.09]
#  [185.17]
#  [191.76]
#  [185.89]
#  [196.44]
#  [192.47]
#  [189.75]
#  [197.2 ]
#  [196.77]
#  [200.72]]

# %%
plt.plot(moving_avg)
plt.plot(delete_intvl)
plt.title('Moving Average Mirror for FB')
plt.xlabel('Days')
plt.ylabel('Prices')
# Out:
# Text(0, 0.5, 'Prices')
